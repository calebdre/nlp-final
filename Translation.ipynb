# %% [markdown]
# # Translation (VI - EN, ZH - EN)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import torch
import torch.nn as nn 
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from io import open
from collections import Counter
from functools import partial
import unicodedata
import re
from torch.autograd import Variable
from gensim.models import KeyedVectors
from gensim.models.wrappers import FastText
import sacrebleu
import random
import time
from datetime import datetime
import pickle as pkl
import string
import os
from os import listdir 
from ast import literal_eval
from sklearn.metrics import confusion_matrix
import matplotlib.style
import matplotlib as mpl
import pickle
import math
from collections import OrderedDict


pd.set_option('max_colwidth',100)
mpl.style.use('bmh')
# %matplotlib inline
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Process Raw Data

# %%
RESERVED_TOKENS = {'<SOS>': 0, '<EOS>': 1, '<PAD>': 2, '<UNK>': 3}

# %%
def text2tokens(raw_text_fp, src_or_targ): 
    """ 
    Take the raw texts filepath and ('target' or 'source') and 
    output the list of tokenized data, each representing a sentence of words
    """
    with open(raw_text_fp) as f:
        tokens_data = [line.lower().split() for line in f.readlines()]
        if src_or_targ == 'source': 
            tokens_data = [datum + ['<EOS>'] for datum in tokens_data]
        elif src_or_targ == 'target': 
            tokens_data = [['<SOS>'] + datum + ['<EOS>'] for datum in tokens_data]
    return tokens_data 


def load_word2vec(lang_type): 
    """ 
    Loads pretrained vectors for a given language 'zh', 'vi' 'en'
    """
    filepath = "wiki.{}.vec".format(lang_type)
    word2vec = KeyedVectors.load_word2vec_format(filepath)
    return word2vec

def build_vocab(tokens_data, max_vocab_size, word2vec): 
    """ 
    Take a list of tokenized sentences of words, max vocabulary size and word2vec model
    Return id2token: a list of tokens, where id2token[i] returns token that corresponds to i-th token 
    and    token2id: dictionary where each key represent a token and value is its index
    Note that the vocab will comprise max_vocab_size-len(RESERVED_TOKENS) tokens that are in word2vec model 
    """
    num_vocab = max_vocab_size - len(RESERVED_TOKENS)
    all_tokens = [token for sentence in tokens_data for token in sentence]
    token_counter = Counter(all_tokens)  # return a dictionary
    vocab, count = zip(*token_counter.most_common(num_vocab))
    id2token = list(RESERVED_TOKENS.keys()) + list(vocab)
    token2id = dict(zip(id2token, range(max_vocab_size)))
    
    # check out how many words are in word2vec vs. not 
    not_in_word2vec = [1 for token in token2id if token not in word2vec]
    pct_of_corpus = 100 * sum([token_counter[token] for token in token_counter if token not in word2vec]) / len(all_tokens)
    
    print("A vocabulary of {} is generated from a set of {} unique tokens.".format(len(token2id), len(token_counter)))
    print("{} vocab tokens are not in word2vec, comprising {:.1f}% of entire corpus.".format(len(not_in_word2vec), pct_of_corpus))
    
    return token2id, id2token 

def tokens2indices(tokens_data, token2id): 
    """ 
    Take tokenized data and token2id dictionary and returns indexed data with <UNK> padding 
    """
    indices_data = [] 
    for datum in tokens_data: 
        indices_datum = [token2id[token] if token in token2id else RESERVED_TOKENS['<UNK>'] for token in datum ]
        indices_data.append(indices_datum)    
    return indices_data

def get_filepath(split, src_lang, targ_lang, src_or_targ): 
    """ Locates data filepath given data split type (train/dev/test), translation pairs (src_lang -> targ_lang), 
        and the language type (source or target) 
    """
    folder_name = "iwslt-{}-{}/".format(src_lang, targ_lang)
    if src_or_targ == 'source':
        file_name = "{}.tok.{}".format(split, src_lang)
    elif src_or_targ == 'target': 
        file_name = "{}.tok.{}".format(split, targ_lang)
    return folder_name + file_name 


def get_filepaths(src_lang, targ_lang): 
    """ 
    Take source language and target language. 
    Return a nested dictionary containing the filepaths for source/target data for train/dev/test sets  
    ex. get_filepaths('zh', 'en') gives
    {'languages': {'source': 'zh', 'target': 'en'},
     'train': {'source': {'filepath': 'iwslt-zh-en/train.tok.zh'},
      'target': {'filepath': 'iwslt-zh-en/train.tok.en'}},
     'dev': {'source': {'filepath': 'iwslt-zh-en/dev.tok.zh'},
      'target': {'filepath': 'iwslt-zh-en/dev.tok.en'}},
     'test': {'source': {'filepath': 'iwslt-zh-en/test.tok.zh'},
      'target': {'filepath': 'iwslt-zh-en/test.tok.en'}}}
    """
    fps = {} 
    
    # store language names 
    fps['languages'] = {} 
    fps['languages']['source'] = src_lang
    fps['languages']['target'] = targ_lang 
    
    # store filepaths 
    for split in ['train', 'dev', 'test']: 
        fps[split] = {} 
        for src_or_targ in ['source', 'target']: 
            fps[split][src_or_targ] = {} 
            fps[split][src_or_targ]['filepath'] = get_filepath(split, src_lang, targ_lang, src_or_targ)
            
    return fps

# %% [markdown]
# # Generate the Vocabulary of Train data using word2vec

# %%
def generate_vocab(src_lang, targ_lang, src_vocab_size, targ_vocab_size):
    """ 
    Input source and target language names and vocab sizes
    Output a nested dictionary vocab containing token2id, id2token, and word2vec for both source and target languages. 
    The first level of keys is language name (e.x 'zh'), and that of nested dictionary are token2id, id2token, and reduced word2vec.
    """
    
    vocab = {} 
    for lang, vocab_size in zip([src_lang, targ_lang], [src_vocab_size, targ_vocab_size]): 
        
        # load train data 
        train_data_fp = get_filepath(split='train', src_lang=src_lang, targ_lang=targ_lang, 
                                     src_or_targ='target' if lang == 'en' else 'source')
        with open(train_data_fp) as f:
            train_tokens = [line.lower().split() for line in f.readlines()]        
        
        # load word embeddings, generate token2id and id2token 
        word2vec_full = load_word2vec(lang)
        token2id, id2token = build_vocab(train_tokens, vocab_size, word2vec_full) 
        word2vec_reduced = {word: word2vec_full[word] for word in token2id if word in word2vec_full} 
        
        # store token2id, id2token, and word embeddings as a dict in nested dict lang 
        vocab[lang] = {'token2id': token2id, 'id2token': id2token, 'word2vec': word2vec_reduced}
        
    return vocab

# %% [markdown]
# ### Chinese to English

# %%
dd = 'zh'
TARG_LANG = 'en'
SRC_VOCAB_SIZE = 30000  # Maybe enlarge our vocabulary size
TARG_VOCAB_SIZE = 30000

# %%
vocab = generate_vocab(SRC_LANG, TARG_LANG, SRC_VOCAB_SIZE, TARG_VOCAB_SIZE)
# vocab['zh']['id2token'], vocab['en']['token2id'], vocab['zh']['word2vec'] 
# vocabulary of train data of both source and target language
# Out:
# A vocabulary of 30000 is generated from a set of 88421 unique tokens.
# 11854 vocab tokens are not in word2vec, comprising 11.0% of entire corpus.
# A vocabulary of 30000 is generated from a set of 60694 unique tokens.
# 1792 vocab tokens are not in word2vec, comprising 3.6% of entire corpus.

# %% [markdown]
# #### Pickle the zh and en Data

# %%
#pickle.dump(vocab, open( "zh_en_vocab.p", "wb"))
vocab_zh_en = pickle.load( open( "zh_en_vocab.p", "rb"))

# %% [markdown]
# #### Get the tokenized data and its index in our vocubulary

# %%
def process_data(src_lang, targ_lang, src_max_sentence_len, targ_max_sentence_len, vocab, sample_limit=None, filter_long=True): 
    """ 
    Input source and target language names and maximum sentence length, vocab returned from generate_vocab, 
    and an optional sample_limit representing the number of sentences to subset if necessary. 
    Output data as a nested dictionary containing the indices and tokens of train/dev/test data for both source and target languages. 
    Note the hierachy of data dict is: data[split][lang_type]['tokens' or 'indices'], 
    e.x. to access indices of source training data, use data['train']['source']['indices']
    """ 
    
    # get filepaths 
    data = get_filepaths(src_lang, targ_lang) # data is a file path!!!!
    
    # loop through each file, read in text, convert to tokens, then to indices 
    for split in ['train', 'dev', 'test']: 
        for src_or_targ in ['source', 'target']: 
            # read in tokens 
            data[split][src_or_targ]['tokens'] = text2tokens(data[split][src_or_targ]['filepath'], src_or_targ)
    
    # for training data, keep only pairs with both source and target sentences within max_sent_len 
    if filter_long:                
        original_train_size = len(data['train']['source']['tokens'])
        source_lengths = np.array([len(l) for l in data['train']['source']['tokens']])
        target_lengths = np.array([len(l) for l in data['train']['target']['tokens']])
        keep_mask = (source_lengths <= src_max_sentence_len) & (target_lengths <= targ_max_sentence_len)
        data['train']['source']['tokens'] = list(np.array(data['train']['source']['tokens'])[keep_mask])
        data['train']['target']['tokens'] = list(np.array(data['train']['target']['tokens'])[keep_mask])
        new_train_size = len(data['train']['source']['tokens']) 
        print("{} data points are removed from training data after filtering out long sentences: {} remain.".format(
            new_train_size - original_train_size, new_train_size))

    # further limit number of samples if applicable 
    if sample_limit is not None: 
        for split in ['train', 'dev', 'test']: 
            for lang_type in ['source', 'target']: 
                data[split][lang_type]['tokens'] = data[split][lang_type]['tokens'][:sample_limit]

    # convert tokens to indices 
    for split in ['train', 'dev', 'test']: 
        for lang_type in ['source', 'target']: 
            data[split][lang_type]['indices'] = tokens2indices(tokens_data=data[split][lang_type]['tokens'],  
                                                        token2id = vocab[data['languages'][lang_type]]['token2id'])

    return data

# %%
SRC_MAX_SENTENCE_LEN = 10
TARG_MAX_SENTENCE_LEN = 10
data = process_data(SRC_LANG, TARG_LANG, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, vocab_zh_en, filter_long=False)
# data['train']['source']['indices'], data['train']['source']['tokens']   for train val, test, source, target, indices, tokens

# %%
data['train']['source']['tokens']
# Out:
# [['深海', '海中', '的', '生命', '大卫', '盖罗', '<EOS>'],
#  ['大卫',
#   '盖罗',
#   '通过',
#   '潜水',
#   '潜水艇',
#   '拍下',
#   '的',
#   '影片',
#   '把',
#   '我们',
#   '带到',
#   '了',
#   '地球',
#   '最',
#   '黑暗',
#   '最',
#   '险恶',
#   '同时',
#   '也',
#   '最美',
#   '美丽',
#   '的',
#   '生物',
#   '栖息',
#   '栖息地',
#   '这里',
#   '是',
#   '海洋',
#   '深处',
#   '的',
#   '峡谷',
#   '和',
#   '火山',
#   '山脊',
#   '这里',
#   '怪诞',
#   '适应',
#   '适应力',
#   '应力',
#   '强',
#   '而且',
#   '数量',
#   '惊人',
#   '的',
#   '生命',
#   '<EOS>'],
#  ['大卫', '盖罗', '这位', '是', '比尔', '兰格', '我', '是', '大卫', '盖罗', '<EOS>'],
#  ['我们',
#   '将',
#   '用',
#   '一些',
#   '影片',
#   '来讲',
#   '讲述',
#   '一些',
#   '深海',
#   '海里',
#   '的',
#   '故事',
#   '<EOS>'],
#  ['我们',
#   '这',
#   '有',
#   '不少',
#   '精彩',
#   '的',
#   '泰坦',
#   '泰坦尼克',
#   '坦尼',
#   '尼克',
#   '的',
#   '影片',
#   '可惜',
#   '您',
#   '今天',
#   '看不到',
#   '不到',
#   '<EOS>'],
#  ['泰坦',
#   '泰坦尼克',
#   '泰坦尼克号',
#   '坦尼',
#   '尼克',
#   '号',
#   '是',
#   '拿',
#   '了',
#   '不少',
#   '票房',
#   '冠军',
#   '但',
#   '事实',
#   '事实上',
#   '它',
#   '并',
#   '不是',
#   '关于',
#   '于海洋',
#   '海洋',
#   '的',
#   '最',
#   '刺激',
#   '的',
#   '故事',
#   '<EOS>'],
#  ['原因', '在于', '我们', '一直', '没', '把', '海洋', '当回事', '回事', '回事儿', '事儿', '<EOS>'],
#  ['大家', '想想', '海洋', '占', '了', '地球', '球面', '面积', '的', '75', '<EOS>'],
#  ['地球', '的', '大部', '大部分', '部分', '都', '是', '海水', '<EOS>'],
#  ['海洋', '的', '平均', '深度', '是', '两英里', '英里', '<EOS>'],
#  ['当',
#   '你',
#   '站',
#   '在',
#   '海滩',
#   '上',
#   '或是',
#   '当',
#   '你',
#   '看到',
#   '海洋',
#   '里',
#   '的',
#   '图像',
#   '当',
#   '你',
#   '看着',
#   '这么',
#   '一大',
#   '大片',
#   '蓝色',
#   '它',
#   '泛',
#   '着',
#   '光',
#   '不断',
#   '地',
#   '变动',
#   '着',
#   '一会',
#   '一会儿',
#   '会儿',
#   '是',
#   '海浪',
#   '一会',
#   '一会儿',
#   '会儿',
#   '是',
#   '波涛',
#   '一会',
#   '一会儿',
#   '会儿',
#   '又',
#   '涨潮',
#   '你',
#   '却',
#   '不知',
#   '知道',
#   '它',
#   '里面',
#   '到底',
#   '有些',
#   '什么',
#   '<EOS>'],
#  ['其实', '实地', '地球', '上', '最长', '的', '山脉', '都', '在', '海洋', '里', '<EOS>'],
#  ['大部', '大部分', '部分', '的', '动物', '也', '都', '生活', '在', '海洋', '里', '<EOS>'],
#  ['大多',
#   '大多数',
#   '多数',
#   '地震',
#   '和',
#   '火山',
#   '喷发',
#   '也',
#   '都',
#   '发生',
#   '生在',
#   '海洋',
#   '里',
#   '在',
#   '海洋',
#   '的',
#   '最',
#   '底部',
#   '<EOS>'],
#  ['海洋',
#   '里',
#   '生物',
#   '的',
#   '多样',
#   '多样性',
#   '和',
#   '密度',
#   '要',
#   '比',
#   '雨林',
#   '林带',
#   '还',
#   '高',
#   '<EOS>'],
#  ['这儿',
#   '基本',
#   '基本上',
#   '都',
#   '没有',
#   '被',
#   '开发',
#   '发过',
#   '但是',
#   '像',
#   '这些',
#   '美丽',
#   '的',
#   '景色',
#   '它',
#   '吸引',
#   '引着',
#   '我们',
#   '并',
#   '被',
#   '我们',
#   '所',
#   '熟知',
#   '<EOS>'],
#  ['但',
#   '我',
#   '想',
#   '告诉',
#   '你',
#   '的',
#   '是',
#   '当',
#   '你',
#   '站',
#   '在',
#   '海边',
#   '时',
#   '你',
#   '面对',
#   '的',
#   '是',
#   '一个',
#   '完全',
#   '陌生',
#   '的',
#   '世界',
#   '<EOS>'],
#  ['我们',
#   '得用',
#   '非常',
#   '特殊',
#   '的',
#   '仪器',
#   '才能',
#   '能到',
#   '到达',
#   '那个',
#   '陌生',
#   '的',
#   '世界',
#   '<EOS>'],
#  ['我们',
#   '用',
#   '的',
#   '是',
#   '深海',
#   '潜水',
#   '潜水艇',
#   'alvin',
#   '号',
#   '和',
#   '摄像',
#   '摄像机',
#   '摄像',
#   '摄像机',
#   '是',
#   '比尔',
#   '兰格',
#   '和',
#   '索尼',
#   '共同',
#   '研发',
#   '的',
#   '<EOS>'],
#  ['马塞尔',
#   '塞尔',
#   '普鲁斯',
#   '普鲁斯特',
#   '斯特',
#   '说',
#   '过',
#   '真正',
#   '的',
#   '探索',
#   '探索之旅',
#   '不是',
#   '为了',
#   '新',
#   '的',
#   '发现',
#   '而是',
#   '为了',
#   '找到',
#   '新',
#   '的',
#   '视角',
#   '<EOS>'],
#  ['和',
#   '我们',
#   '合作',
#   '的',
#   '人们',
#   '帮',
#   '我们',
#   '找到',
#   '了',
#   '新',
#   '的',
#   '视角',
#   '我们',
#   '不仅',
#   '看到',
#   '了',
#   '哪些',
#   '已经',
#   '存在',
#   '的',
#   '那些',
#   '深海',
#   '海里',
#   '的',
#   '景观',
#   '同时',
#   '我们',
#   '也',
#   '重新',
#   '重新认识',
#   '认识',
#   '了',
#   '生命',
#   '本身',
#   '<EOS>'],
#  ['这', '是', '一只', '水母', '<EOS>'],
#  ['是', '我', '最', '喜欢', '的', '因为', '它', '哪', '都', '能动', '<EOS>'],
#  ['原来', '它', '是', '海洋', '洋中', '最长', '的', '生物', '<EOS>'],
#  ['它', '可以', '伸展', '伸展到', '150', '英尺', '长', '<EOS>'],
#  ['看到', '这些', '在', '动', '的', '东西', '了', '吗', '<EOS>'],
#  ['我', '真', '喜欢', '这些', '东西', '<EOS>'],
#  ['底下',
#   '这些',
#   '都',
#   '是',
#   '鱼饵',
#   '它们',
#   '上上',
#   '上上下下',
#   '上下',
#   '下下',
#   '的',
#   '浮动',
#   '<EOS>'],
#  ['还有', '这些', '摇晃', '着', '旋转', '转着', '的', '触角', '<EOS>'],
#  ['这', '是', '一种', '种群', '栖', '动物', '<EOS>'],
#  ['其实',
#   '它们',
#   '都',
#   '是',
#   '由',
#   '单独',
#   '的',
#   '动物',
#   '结合',
#   '合在',
#   '合在一起',
#   '一起',
#   '就',
#   '成',
#   '了',
#   '这样',
#   '大',
#   '的',
#   '一个',
#   '生物',
#   '<EOS>'],
#  ['还有',
#   '前面',
#   '的',
#   '这个',
#   '是',
#   '推进',
#   '引擎',
#   '它',
#   '一会',
#   '一会儿',
#   '会儿',
#   '会用',
#   '用到',
#   '它',
#   '还有',
#   '一些',
#   '光',
#   '<EOS>'],
#  ['如果',
#   '你',
#   '把',
#   '所有',
#   '的',
#   '鱼类',
#   '放在',
#   '天平',
#   '的',
#   '一端',
#   '然后',
#   '把',
#   '所有',
#   '水母',
#   '状',
#   '的',
#   '动物',
#   '放在',
#   '另一端',
#   '一端',
#   '水母',
#   '那边',
#   '要',
#   '重',
#   '的',
#   '多',
#   '<EOS>'],
#  ['大多',
#   '大多数',
#   '多数',
#   '的',
#   '海洋',
#   '海洋生物',
#   '生物',
#   '都',
#   '是',
#   '由',
#   '这类',
#   '生物',
#   '<EOS>'],
#  ['这', '只是', 'x', '翼', '死亡', '水母', '<EOS>'],
#  ['它们', '用', '这种', '生物', '荧光', '来', '吸引', '伴侣', '食物', '和', '交流', '<EOS>'],
#  ['我们', '没办', '办法', '从', '我们', '档案', '中', '的', '水母', '介绍', '起', '<EOS>'],
#  ['它们', '大小', '不同', '形状', '各异', '<EOS>'],
#  ['比尔',
#   '兰格',
#   '我们',
#   '通常',
#   '忘',
#   '了',
#   '海洋',
#   '平均',
#   '有',
#   '好几',
#   '几英里',
#   '英里',
#   '深',
#   '我们',
#   '对于',
#   '两三',
#   '两三百',
#   '三百',
#   '三百尺',
#   '百尺',
#   '深处',
#   '的',
#   '动物',
#   '很',
#   '了解',
#   '但',
#   '从',
#   '那',
#   '往下',
#   '就',
#   '不',
#   '太',
#   '知道',
#   '了',
#   '<EOS>'],
#  ['而',
#   '像',
#   '这样',
#   '的',
#   '动物',
#   '就',
#   '生活',
#   '在',
#   '我们',
#   '没有',
#   '探索',
#   '过',
#   '的',
#   '微重力',
#   '重力',
#   '的',
#   '三维',
#   '三维空间',
#   '维空间',
#   '空间',
#   '里',
#   '<EOS>'],
#  ['你',
#   '一定',
#   '听说',
#   '过',
#   '巨型',
#   '章鱼',
#   '之类',
#   '的',
#   '东西',
#   '但',
#   '像',
#   '这样',
#   '的',
#   '动物',
#   '可以',
#   '伸张',
#   '到',
#   '140',
#   '到',
#   '160',
#   '英尺',
#   '长',
#   '<EOS>'],
#  ['它们', '还', '没有', '被', '研究', '透', '<EOS>'],
#  ['大卫',
#   '这',
#   '也',
#   '是',
#   '其中',
#   '之一',
#   '是',
#   '我们',
#   '另',
#   '一个',
#   '最爱',
#   '一个',
#   '小',
#   '的',
#   '八',
#   '爪',
#   '鱼',
#   '<EOS>'],
#  ['你', '真的', '能', '看穿', '它', '的', '脑袋', '<EOS>'],
#  ['它',
#   '的',
#   '耳朵',
#   '在',
#   '上下',
#   '下摆',
#   '摆动',
#   '还',
#   '很',
#   '优雅',
#   '地',
#   '向上',
#   '上游',
#   '着',
#   '<EOS>'],
#  ['我们',
#   '能',
#   '在',
#   '不同',
#   '深度',
#   '甚至',
#   '最深',
#   '最深处',
#   '深处',
#   '看到',
#   '这样',
#   '的',
#   '动物',
#   '<EOS>'],
#  ['它们', '有', '的', '几', '英尺', '长', '有', '的', '几尺', '长', '<EOS>'],
#  ['它们',
#   '有',
#   '的',
#   '会',
#   '贴近',
#   '潜水',
#   '潜水艇',
#   '它们',
#   '的',
#   '眼睛',
#   '会',
#   '贴着',
#   '潜水',
#   '潜水艇',
#   '的',
#   '窗口',
#   '向',
#   '里',
#   '看',
#   '<EOS>'],
#  ['这里',
#   '的',
#   '世界',
#   '中',
#   '还有',
#   '另',
#   '一个',
#   '世界',
#   '我们',
#   '将',
#   '给',
#   '您',
#   '介绍',
#   '两个',
#   '<EOS>'],
#  ['像',
#   '这',
#   '一个',
#   '当',
#   '我们',
#   '到达',
#   '了',
#   '中海',
#   '一下',
#   '就',
#   '能',
#   '看见',
#   '像',
#   '这样',
#   '样子',
#   '的',
#   '物种',
#   '<EOS>'],
#  ['它', '看起', '看起来', '起来', '有点', '有点像', '深海', '海里', '的', '公鸡', '<EOS>'],
#  ['看', '这个', '它', '看起', '看起来', '起来', '真的', '太', '正经', '了', '<EOS>'],
#  ['还有', '这', '也', '是', '我', '的', '最爱', '之一', '看', '这', '张', '脸', '<EOS>'],
#  ['你们', '看到', '的', '这些', '基本', '基本上', '都', '是', '科学', '数据', '<EOS>'],
#  ['它们',
#   '都',
#   '是',
#   '我们',
#   '为了',
#   '科学',
#   '科学研究',
#   '研究',
#   '而',
#   '收集',
#   '的',
#   '影片',
#   '<EOS>'],
#  ['这个',
#   '是',
#   '比尔',
#   '正在',
#   '做',
#   '的',
#   '为了',
#   '让',
#   '科学',
#   '科学家',
#   '学家',
#   '们',
#   '看到',
#   '这些',
#   '第一',
#   '第一手',
#   '一手',
#   '材料',
#   '这些',
#   '在',
#   '它们',
#   '生存',
#   '的',
#   '环境',
#   '中',
#   '获取',
#   '的',
#   '<EOS>'],
#  ['他们', '不会', '会用', '鱼网', '来', '捕', '这些', '生物', '<EOS>'],
#  ['他们', '会', '在', '它们', '的', '世界', '中观', '观察', '它们', '<EOS>'],
#  ['我们',
#   '会用',
#   '一个',
#   '控制',
#   '控制杆',
#   '在',
#   '地面',
#   '面上',
#   '我们',
#   '只用',
#   '坐在',
#   '电脑',
#   '电脑前',
#   '移动',
#   '控制',
#   '控制杆',
#   '就',
#   '能',
#   '环游',
#   '地球',
#   '了',
#   '<EOS>'],
#  ['现在',
#   '我们',
#   '看',
#   '一个',
#   '海中',
#   '中央',
#   '的',
#   '山脊',
#   '一个',
#   '40',
#   '000',
#   '英里',
#   '里长',
#   '的',
#   '山脉',
#   '<EOS>'],
#  ['这些', '山脉', '顶端', '端的', '平均', '深度', '都', '有', '1', '5', '英里', '<EOS>'],
#  ['我们',
#   '已',
#   '走遍',
#   '了',
#   '大西',
#   '大西洋',
#   '西洋',
#   '那',
#   '就是',
#   '山脊',
#   '现在',
#   '我们',
#   '要',
#   '穿过',
#   '加勒',
#   '加勒比',
#   '加勒比海',
#   '中美',
#   '中美洲',
#   '美洲',
#   '最后',
#   '到达',
#   '太平',
#   '太平洋',
#   '北纬',
#   '九度',
#   '<EOS>'],
#  ['我们',
#   '用',
#   '声纳',
#   '来',
#   '制作',
#   '这些',
#   '山脊',
#   '的',
#   '地图',
#   '这',
#   '是',
#   '这些',
#   '山脊',
#   '脊中',
#   '的',
#   '一个',
#   '<EOS>'],
#  ['我们', '现在', '向右转', '右转', '转过', '一个', '悬崖', '<EOS>'],
#  ['这些',
#   '山脉',
#   '两侧',
#   '山谷',
#   '的',
#   '高度',
#   '大多',
#   '大多数',
#   '多数',
#   '都',
#   '比',
#   '阿尔卑',
#   '阿尔卑斯',
#   '阿尔卑斯山',
#   '阿尔卑斯山脉',
#   '卑斯山',
#   '斯山',
#   '斯山脉',
#   '山脉',
#   '还要',
#   '高',
#   '<EOS>'],
#  ['这里',
#   '还有',
#   '有成',
#   '成千',
#   '成千上万',
#   '千上万',
#   '上万',
#   '的',
#   '山脉',
#   '不在',
#   '地图',
#   '上',
#   '<EOS>'],
#  ['这', '是', '一个', '火山', '山脊', '<EOS>'],
#  ['我们', '现在', '往', '更深', '深处', '走', '<EOS>'],
#  ['最终', '我们', '会', '看到', '像', '这样', '的', '东西', '<EOS>'],
#  ['这',
#   '是',
#   '最',
#   '具',
#   '代表',
#   '代表性',
#   '的',
#   '一个',
#   '机器',
#   '机器人',
#   '他',
#   '叫',
#   '杰',
#   '森',
#   '<EOS>'],
#  ['你',
#   '会',
#   '坐在',
#   '这样',
#   '的',
#   '一间',
#   '房间',
#   '里',
#   '用',
#   '遥控',
#   '杆',
#   '和',
#   '耳机',
#   '来',
#   '这样',
#   '驾驶',
#   '机器',
#   '机器人',
#   '同时',
#   '时机',
#   '机器',
#   '机器人',
#   '在',
#   '海底',
#   '行走',
#   '<EOS>'],
#  ['在',
#   '伍兹霍',
#   '霍尔',
#   '我们',
#   '还',
#   '希望',
#   '和',
#   '我们',
#   '的',
#   '合伙',
#   '合伙人',
#   '把',
#   '这个',
#   '虚拟',
#   '的',
#   '世界',
#   '这个',
#   '未曾',
#   '背',
#   '发掘',
#   '的',
#   '地带',
#   '带回',
#   '实验',
#   '实验室',
#   '室里',
#   '<EOS>'],
#  ['因为', '我们', '现在', '看到', '的', '都', '是', '些', '点滴', '片断', '<EOS>'],
#  ['我们',
#   '获取',
#   '了',
#   '一些',
#   '声音',
#   '一些',
#   '影象',
#   '或是',
#   '一些',
#   '图片',
#   '或是',
#   '一些',
#   '化学',
#   '化学成分',
#   '学成',
#   '成分',
#   '但',
#   '我们',
#   '从没',
#   '把',
#   '它们',
#   '放在',
#   '一块',
#   '来看',
#   '<EOS>'],
#  ['这里', '是', '比尔', '的', '相机', '真正', '正出', '出彩', '的', '地方', '<EOS>'],
#  ['我们', '叫', '这个', '热泉', '喷出', '出口', '<EOS>'],
#  ['您',
#   '现在',
#   '看到',
#   '的',
#   '是',
#   '一团',
#   '密度',
#   '很',
#   '高',
#   '的',
#   '强',
#   '硫化',
#   '氫',
#   '液体',
#   '从',
#   '海底',
#   '的',
#   '火山',
#   '山中',
#   '中轴',
#   '喷出',
#   '<EOS>'],
#  ['有时', '可以', '达到', '600', '到', '700', '华氏', '华氏度', '<EOS>'],
#  ['这些',
#   '都',
#   '是',
#   '海水',
#   '水中',
#   '的',
#   '液体',
#   '一点',
#   '五英里',
#   '英里',
#   '两英里',
#   '英里',
#   '三英里',
#   '英里',
#   '深',
#   '<EOS>'],
#  ['六七',
#   '六七十',
#   '六七十年',
#   '六七十年代',
#   '七十',
#   '七十年',
#   '七十年代',
#   '十年',
#   '十年代',
#   '年代',
#   '时',
#   '我们',
#   '只',
#   '知道',
#   '这',
#   '是',
#   '一座',
#   '火山',
#   '<EOS>'],
#  ['后来',
#   '我们',
#   '发现',
#   '了',
#   '这些',
#   '物质',
#   '存在',
#   '在于',
#   '它',
#   '的',
#   '轴心',
#   '周围',
#   '因为',
#   '假如',
#   '你',
#   '知道',
#   '这里',
#   '有',
#   '火山',
#   '运动',
#   '这些',
#   '液体',
#   '体会',
#   '流向',
#   '向海',
#   '海底',
#   '并且',
#   '进入',
#   '入海',
#   '海床',
#   '的',
#   '裂缝',
#   '和',
#   '岩浆',
#   '汇合',
#   '然后',
#   '喷出',
#   '热浪',
#   '<EOS>'],
#  ['我们',
#   '真没想到',
#   '没想',
#   '没想到',
#   '想到',
#   '硫化',
#   '硫化氢',
#   '化氢',
#   '的',
#   '含量',
#   '会',
#   '这么',
#   '高',
#   '<EOS>'],
#  ['我们',
#   '当初',
#   '根本',
#   '不知',
#   '知道',
#   '这些',
#   '是',
#   '什么',
#   '我们',
#   '叫',
#   '它们',
#   '烟囱',
#   '<EOS>'],
#  ['这', '是', '这些', '热液', '出口', '口中', '的', '一个', '<EOS>'],
#  ['300', '多度', '的', '液体', '从', '地里', '涌出', '<EOS>'],
#  ['我们',
#   '两侧',
#   '的',
#   '山脊',
#   '都',
#   '比',
#   '阿尔卑',
#   '阿尔卑斯',
#   '阿尔卑斯山',
#   '卑斯山',
#   '斯山',
#   '山高',
#   '所以',
#   '说',
#   '这',
#   '的',
#   '地形',
#   '是',
#   '惊人',
#   '的',
#   '<EOS>'],
#  ['比尔',
#   '这些',
#   '白色',
#   '的',
#   '物质',
#   '是',
#   '一种',
#   '细菌',
#   '它',
#   '能',
#   '在',
#   '180',
#   '度',
#   '的',
#   '高温',
#   '下生',
#   '生存',
#   '<EOS>'],
#  ['大卫',
#   '现在',
#   '我们',
#   '要',
#   '讲',
#   '一个',
#   '最',
#   '不可',
#   '不可思议',
#   '思议',
#   '的',
#   '故事',
#   '我们',
#   '现在',
#   '看到',
#   '的',
#   '是',
#   '我们',
#   '最',
#   '开始',
#   '看到',
#   '的',
#   '从',
#   '海底',
#   '冒出',
#   '冒出来',
#   '出来',
#   '的',
#   '火山',
#   '喷发',
#   '后',
#   '的',
#   '细菌',
#   '<EOS>'],
#  ['我们', '开始', '想', '它', '为什么', '什么', '在', '那里', '<EOS>'],
#  ['我们', '现在', '知道', '它', '可能', '是', '来自', '地球', '内部', '<EOS>'],
#  ['它',
#   '不仅',
#   '从',
#   '地球',
#   '里',
#   '出来',
#   '它',
#   '的',
#   '生物',
#   '源',
#   '来自',
#   '于',
#   '火山',
#   '活动',
#   '但',
#   '这些',
#   '细菌',
#   '供养',
#   '群居',
#   '在',
#   '这里',
#   '的',
#   '生物',
#   '<EOS>'],
#  ['这里', '的', '压力', '是', '平均', '每平方', '平方', '平方英尺', '英尺', '4000', '磅', '<EOS>'],
#  ['离地',
#   '地表',
#   '一点',
#   '五英里',
#   '英里',
#   '两三',
#   '三英里',
#   '英里',
#   '深',
#   '没有',
#   '任何',
#   '阳光',
#   '的',
#   '照射',
#   '<EOS>'],
#  ['支撑',
#   '所有',
#   '的',
#   '生命',
#   '形式',
#   '的',
#   '能量',
#   '都',
#   '来自',
#   '地球',
#   '内部',
#   '那些',
#   '化学',
#   '化学合成',
#   '合成',
#   '合成物',
#   '<EOS>'],
#  ['你', '可以', '看到', '这', '的', '生物', '密度', '是', '多', '大', '<EOS>'],
#  ['它们', '被叫', '叫做', '管道', '蠕虫', '<EOS>'],
#  ['比尔', '这些', '蠕虫', '没有', '消化', '消化系', '消化系统', '系统', '它们', '没有', '嘴', '<EOS>'],
#  ['但', '它们', '有', '两种', '腮', '组织', '<EOS>'],
#  ['一种',
#   '可以',
#   '从',
#   '深海',
#   '液体',
#   '中',
#   '吸收',
#   '氧气',
#   '另',
#   '一种',
#   '吞',
#   '近',
#   '这些',
#   '靠',
#   '热液',
#   '生存',
#   '的',
#   '化合',
#   '细菌',
#   '就是',
#   '这些',
#   '从',
#   '海底',
#   '冒出',
#   '冒出来',
#   '出来',
#   '的',
#   '热水',
#   '然后',
#   '再',
#   '转化',
#   '转化成',
#   '化成',
#   '管道',
#   '蠕虫',
#   '可以',
#   '消化',
#   '的',
#   '简单',
#   '单糖',
#   '糖份',
#   '<EOS>'],
#  ['大卫', '你', '可以', '看到', '这', '是', '一只', '生活', '在', '这里', '的', '螃蟹', '<EOS>'],
#  ['它', '能', '钳', '住', '蠕虫', '的', '一小', '一小部分', '小部', '部分', '<EOS>'],
#  ['它们', '通常', '一', '碰到', '螃蟹', '就', '缩回', '缩回去', '回去', '<EOS>'],
#  ['恩', '厉害', '<EOS>'],
#  ['所以',
#   '一旦',
#   '螃蟹',
#   '碰到',
#   '它们',
#   '它们',
#   '就',
#   '缩回',
#   '壳里',
#   '就',
#   '像',
#   '指甲',
#   '<EOS>'],
#  ['这样',
#   '的',
#   '故事',
#   '被',
#   '一一',
#   '一展',
#   '展开',
#   '我们',
#   '只是',
#   '开始',
#   '对',
#   '它们',
#   '有些',
#   '认识',
#   '全都',
#   '靠',
#   '这个',
#   '新',
#   '的',
#   '摄影',
#   '技术',
#   '<EOS>'],
#  ['比尔', '这些', '蠕虫', '都', '生活', '在', '这样', '极端', '端的', '温度', '下', '<EOS>'],
#  ['它们',
#   '的',
#   '脚',
#   '有',
#   '大概',
#   '200',
#   '度',
#   '它们',
#   '的',
#   '头',
#   '是',
#   '3',
#   '度',
#   '左右',
#   '这',
#   '就',
#   '像是',
#   '你',
#   '的',
#   '手',
#   '放在',
#   '沸水',
#   '水中',
#   '而',
#   '你',
#   '的',
#   '脚',
#   '在',
#   '冰水',
#   '水里',
#   '<EOS>'],
#  ['它们', '就是', '这样', '生活', '的', '<EOS>'],
#  ['大卫', '这', '是', '一只', '雌性', '蠕虫', '<EOS>'],
#  ['这', '只是', '雄性', '的', '<EOS>'],
#  ['你',
#   '看着',
#   '用不着',
#   '不着',
#   '多久',
#   '它们',
#   '两',
#   '就',
#   '会',
#   '出现',
#   '现在',
#   '这',
#   '开始',
#   '打斗',
#   '<EOS>'],
#  ['你',
#   '所',
#   '看到',
#   '的',
#   '都',
#   '是',
#   '在',
#   '深海',
#   '最',
#   '漆黑',
#   '的',
#   '地方',
#   '进行',
#   '的',
#   '<EOS>'],
#  ['除了',
#   '我们',
#   '带来',
#   '过',
#   '的',
#   '光线',
#   '之外',
#   '没有',
#   '任何',
#   '何其',
#   '其他',
#   '的',
#   '光线',
#   '<EOS>'],
#  ['看', '这里', '<EOS>'],
#  ['在',
#   '过去',
#   '的',
#   '潜水',
#   '水系',
#   '系列',
#   '中',
#   '有',
#   '一次',
#   '我们',
#   '在',
#   '这个',
#   '区域',
#   '里',
#   '找到',
#   '200',
#   '种',
#   '物种',
#   '198',
#   '种',
#   '都',
#   '是',
#   '新',
#   '的',
#   '物种',
#   '<EOS>'],
#  ['比尔',
#   '对生',
#   '生物',
#   '生物学',
#   '生物学家',
#   '学家',
#   '来说',
#   '最大',
#   '的',
#   '问题',
#   '之一',
#   '是',
#   '在',
#   '这些',
#   '地点',
#   '工作',
#   '更',
#   '不用',
#   '不用说',
#   '采集',
#   '物种',
#   '<EOS>'],
#  ['因为',
#   '采集',
#   '上来',
#   '它们',
#   '就',
#   '会',
#   '破裂',
#   '所以',
#   '这些',
#   '影像',
#   '对',
#   '科学',
#   '学来',
#   '来说',
#   '是',
#   '至关',
#   '至关重要',
#   '重要',
#   '的',
#   '<EOS>'],
#  ['大卫', '这', '是', '两条', '在', '两英里', '英里', '深处', '的', '章鱼', '<EOS>'],
#  ['这里',
#   '的',
#   '压力',
#   '真的',
#   '让',
#   '我',
#   '很',
#   '吃惊',
#   '这些',
#   '动物',
#   '居然',
#   '可以',
#   '在',
#   '这样',
#   '的',
#   '深度',
#   '生存',
#   '这里',
#   '的',
#   '压力',
#   '足够',
#   '把',
#   '泰坦',
#   '泰坦尼克',
#   '泰坦尼克号',
#   '坦尼',
#   '尼克',
#   '号',
#   '压',
#   '成',
#   '一只',
#   '空',
#   '百事',
#   '百事可乐',
#   '可乐',
#   '罐',
#   '<EOS>'],
#  ['直到', '直到现在', '现在', '我们', '看到', '的', '都', '来自', '太平', '太平洋', '<EOS>'],
#  ['这些', '是', '来自', '自大', '大西', '大西洋', '西洋', '而且', '更深', '<EOS>'],
#  ['你',
#   '可以',
#   '看到',
#   '这',
#   '只',
#   '虾',
#   '正在',
#   '骚扰',
#   '这个',
#   '可怜',
#   '的',
#   '小东西',
#   '东西',
#   '它',
#   '会用',
#   '它',
#   '的',
#   '爪子',
#   '反抗',
#   '嗷',
#   '<EOS>'],
#  ['类似', '似的', '故事', '一只', '在', '发生', '<EOS>'],
#  ['它们',
#   '在',
#   '这',
#   '只',
#   '蟹',
#   '背上',
#   '能',
#   '获得',
#   '的',
#   '是',
#   '这种',
#   '很',
#   '奇怪',
#   '的',
#   '细菌',
#   '菌类',
#   '的',
#   '食物',
#   '它',
#   '生长',
#   '在',
#   '这些',
#   '动物',
#   '的',
#   '背上',
#   '<EOS>'],
#  ['而',
#   '这些',
#   '虾',
#   '其实',
#   '正在',
#   '这些',
#   '动物',
#   '的',
#   '背上',
#   '上收',
#   '收割',
#   '细菌',
#   '<EOS>'],
#  ['这些', '螃蟹', '可不', '喜欢', '这样', '<EOS>'],
#  ['这些',
#   '蟹',
#   '背上',
#   '的',
#   '长',
#   '的',
#   '细丝',
#   '是',
#   '由',
#   '这种',
#   '细菌',
#   '组成',
#   '的',
#   '<EOS>'],
#  ['所以', '细菌', '可以', '在', '蟹', '背上', '长', '出', '毛', '来', '<EOS>'],
#  ['现在', '你', '又', '看到', '了', '同样', '的', '在', '发生', '<EOS>'],
#  ['这个',
#   '红点',
#   '是',
#   '潜水',
#   '潜水艇',
#   'alvin',
#   '号',
#   '腹',
#   '下',
#   '的',
#   '镭射',
#   '射灯',
#   '能',
#   '让',
#   '我们',
#   '感觉',
#   '到',
#   '我们',
#   '离',
#   '喷出',
#   '出口',
#   '有',
#   '多',
#   '远',
#   '<EOS>'],
#  ['这些', '都', '是', '虾', '<EOS>'],
#  ['你',
#   '可以',
#   '看到',
#   '热液',
#   '从',
#   '这儿',
#   '这儿',
#   '还有',
#   '这儿',
#   '冒出',
#   '冒出来',
#   '出来',
#   '<EOS>'],
#  ['它们',
#   '会',
#   '粘',
#   '在',
#   '岩石',
#   '的',
#   '表面',
#   '并',
#   '从',
#   '岩石',
#   '表面',
#   '把',
#   '细菌',
#   '扒',
#   '下来',
#   '<EOS>'],
#  ['这里', '有', '一个', '很小', '的', '出口', '在', '那个', '很大', '的', '柱子', '上', '<EOS>'],
#  ['这些', '柱子', '可以', '有', '几层', '几层楼', '层楼', '高', '<EOS>'],
#  ['现在',
#   '你',
#   '可以',
#   '看到',
#   '这样',
#   '一个',
#   '难以',
#   '难以置信',
#   '置信',
#   '景色',
#   '色鬼',
#   '鬼魅',
#   '的',
#   '峡谷',
#   '这里',
#   '有',
#   '在',
#   '这样',
#   '的',
#   '柱子',
#   '热泉',
#   '火山',
#   '喷发',
#   '和',
#   '地震',
#   '这些',
#   '奇异',
#   '的',
#   '动物',
#   '就',
#   '生活',
#   '在',
#   '这里',
#   '靠',
#   '地里',
#   '冒出',
#   '的',
#   '化学',
#   '化学能',
#   '能量',
#   '为生',
#   '<EOS>'],
#  ['它们', '毫不', '需要', '阳光', '<EOS>'],
#  ['比尔',
#   '你',
#   '能',
#   '看到',
#   '这些',
#   '虾',
#   '的',
#   '背上',
#   '上有',
#   'v',
#   '形',
#   '的',
#   '记号',
#   '吗',
#   '<EOS>'],
#  ['它们', '实际', '实际上', '是', '感光', '感光器', '光器', '器官', '<EOS>'],
#  ['它们', '就是', '靠', '它', '来', '找到', '热液', '出口', '<EOS>'],
#  ['这些',
#   '出口',
#   '发射',
#   '射出',
#   '一种',
#   '黑体',
#   '的',
#   '辐射',
#   '一种',
#   '红外',
#   '红外线',
#   '外线',
#   '所以',
#   '它们',
#   '能',
#   '在',
#   '很远',
#   '的',
#   '距离',
#   '外',
#   '找到',
#   '这些',
#   '出口',
#   '<EOS>'],
#  ['大卫',
#   '所有',
#   '这些',
#   '都',
#   '发生',
#   '生在',
#   '40000',
#   '英里',
#   '里长',
#   '的',
#   '山脊',
#   '周围',
#   '我们',
#   '称之为',
#   '之为',
#   '为生',
#   '生命',
#   '带',
#   '即使',
#   '是',
#   '今天',
#   '此时',
#   '此时此刻',
#   '此刻',
#   '生命',
#   '正',
#   '诞生',
#   '生于',
#   '火山',
#   '活动',
#   '中',
#   '<EOS>'],
#  ['这', '是', '我们', '在', '这里', '的', '第一', '第一次', '一次', '尝试', '<EOS>'],
#  ['我们',
#   '将',
#   '为',
#   '您',
#   '展示',
#   '高清',
#   '高清晰',
#   '清晰',
#   '的',
#   '太平',
#   '太平洋',
#   '画面',
#   '<EOS>'],
#  ['我们', '现在', '沿着', '根', '柱子', '向上', '走', '<EOS>'],
#  ['它', '有', '好几', '好几层', '几层', '几层楼', '层楼', '高', '<EOS>'],
#  ['在',
#   '这里',
#   '你',
#   '可以',
#   '看到',
#   '这',
#   '是',
#   '很多',
#   '多种',
#   '动物',
#   '的',
#   '栖息',
#   '栖息地',
#   '<EOS>'],
#  ['这',
#   '有',
#   '一个',
#   '滑稽',
#   '的',
#   '热',
#   '盘子',
#   '状',
#   '的',
#   '东西',
#   '热液',
#   '从',
#   '里面',
#   '涌出',
#   '<EOS>'],
#  ['这些', '都', '是', '蠕虫', '们', '单个', '的', '家', '<EOS>'],
#  ['现在', '可以', '更', '近距', '近距离', '距离', '离地', '看到', '这个', '群体', '<EOS>'],
#  ['这里', '有', '蟹', '还有', '蠕虫', '<EOS>'],
#  ['这些', '更', '小', '地动', '动物', '会', '蜷缩', '缩在', '周围', '<EOS>'],
#  ['这', '是', '一个', '塔', '组织', '<EOS>'],
#  ['我', '认为', '这', '是', '看上', '看上去', '上去', '最', '精致', '地', '一个', '<EOS>'],
#  ['我',
#   '真的',
#   '太',
#   '喜欢',
#   '它',
#   '了',
#   '这些',
#   '些小',
#   '烟囱',
#   '上',
#   '冒',
#   '着',
#   '烟',
#   '<EOS>'],
#  ['对了', '这些', '物质', '可是', '带有', '剧毒', '的', '<EOS>'],
#  ['你',
#   '不能',
#   '向海',
#   '海里',
#   '倾倒',
#   '这些',
#   '但',
#   '它',
#   '却',
#   '从',
#   '海底',
#   '自己',
#   '冒出',
#   '冒出来',
#   '出来',
#   '<EOS>'],
#  ['难以',
#   '难以置信',
#   '置信',
#   '这些',
#   '大致',
#   '上',
#   '是',
#   '硫磺',
#   '磺酸',
#   '它们',
#   '以',
#   '惊人',
#   '的',
#   '速度',
#   '向',
#   '外',
#   '涌',
#   '<EOS>'],
#  ['这些',
#   '动物',
#   '在',
#   '努力',
#   '地',
#   '生存',
#   '而',
#   '我们',
#   '也许',
#   '就是',
#   '是从',
#   '这里',
#   '演变',
#   '变来',
#   '地',
#   '<EOS>'],
#  ['我们', '很', '可能', '是从', '这里', '开始', '进化', '<EOS>'],
#  ['比尔',
#   '我们',
#   '刚才',
#   '说',
#   '到',
#   '地',
#   '细菌',
#   '是',
#   '我们',
#   '所知',
#   '知道',
#   '的',
#   '最',
#   '简单',
#   '的',
#   '生命',
#   '形式',
#   '<EOS>'],
#  ['有',
#   '很多',
#   '科学',
#   '小组',
#   '都',
#   '认为',
#   '生命',
#   '是从',
#   '这些',
#   '热液',
#   '喷口',
#   '开始',
#   '进化',
#   '的',
#   '<EOS>'],
#  ['尽管',
#   '这些',
#   '喷口',
#   '的',
#   '存在',
#   '时间',
#   '很',
#   '短',
#   '大概',
#   '每个',
#   '只能',
#   '延续',
#   '10',
#   '年',
#   '左右',
#   '但',
#   '作为',
#   '一个',
#   '生态',
#   '生态系',
#   '生态系统',
#   '系统',
#   '它们',
#   '已经',
#   '很',
#   '稳定',
#   '地',
#   '存在',
#   '了',
#   '几百',
#   '几百万',
#   '百万',
#   '甚至',
#   '几十',
#   '几十亿',
#   '几十亿年',
#   '十亿',
#   '亿年',
#   '<EOS>'],
#  ['大卫',
#   '它们',
#   '运作',
#   '得',
#   '太好了',
#   '你',
#   '看',
#   '这里',
#   '里面',
#   '面有',
#   '很多',
#   '鱼',
#   '<EOS>'],
#  ['这', '是', '一个', '鱼场', '<EOS>'],
#  ['这',
#   '只',
#   '螃蟹',
#   '把',
#   '它',
#   '的',
#   '钳子',
#   '放在',
#   '这',
#   '只管',
#   '管道',
#   '蠕虫',
#   '的',
#   '尾部',
#   '等',
#   '着',
#   '这',
#   '只',
#   '蠕虫',
#   '伸出',
#   '脑袋',
#   '<EOS>'],
#  ['比尔',
#   '生物',
#   '生物学',
#   '生物学家',
#   '学家',
#   '现在',
#   '还',
#   '不能',
#   '能解',
#   '解释',
#   '为什么',
#   '什么',
#   '这些',
#   '动物',
#   '如此',
#   '活跃',
#   '<EOS>'],
#  ['这些', '蠕虫', '每星期', '星期', '长', '好几', '几尺', '<EOS>'],
#  ['大卫',
#   '我',
#   '已经',
#   '说',
#   '过',
#   '这里',
#   '的',
#   '环境',
#   '从',
#   '人类',
#   '的',
#   '角度',
#   '来说',
#   '是',
#   '很',
#   '有毒',
#   '毒性',
#   '的',
#   '<EOS>'],
#  ['不仅',
#   '不仅如此',
#   '如此',
#   '更',
#   '重要',
#   '的',
#   '是',
#   '它',
#   '的',
#   '生命',
#   '源泉',
#   '这个',
#   '向',
#   '喷涌',
#   '管路',
#   '的',
#   '体系',
#   '每隔',
#   '几年',
#   '就',
#   '会',
#   '自动',
#   '关闭',
#   '<EOS>'],
#  ['一旦', '这些', '喷涌', '管路', '系统', '关闭', '这些', '生活', '环境', '就', '迁移', '<EOS>'],
#  ['而且',
#   '这里',
#   '还有',
#   '地震',
#   '每隔',
#   '五年',
#   '就',
#   '有',
#   '一次',
#   '火山',
#   '喷发',
#   '可以',
#   '把',
#   '这里',
#   '的',
#   '生存',
#   '生存环境',
#   '环境',
#   '完全',
#   '摧毁',
#   '<EOS>'],
#  ['尽管',
#   '尽管如此',
#   '如此',
#   '这些',
#   '动物',
#   '还是',
#   '会',
#   '在',
#   '一年',
#   '以后',
#   '又',
#   '长',
#   '回来',
#   '<EOS>'],
#  ['当',
#   '我们',
#   '谈到',
#   '这',
#   '的',
#   '生物',
#   '密度',
#   '和',
#   '生物',
#   '多样',
#   '多样性',
#   '比热',
#   '热带',
#   '热带雨林',
#   '雨林',
#   '还',
#   '高',
#   '它',
#   '这么',
#   '快',
#   '就',
#   '能',
#   '长',
#   '回来',
#   '<EOS>'],
#  ['它', '是否', '是否是', '很', '敏感', '呢', '是', '的', '<EOS>'],
#  ['是否', '是否是', '很', '脆弱', '呢', '不是', '它', '一点', '也', '不', '脆弱', '<EOS>'],
#  ['我', '在', '结束', '前', '还要', '要说', '一个', '故事', '<EOS>'],
#  ['这个',
#   '故事',
#   '事发',
#   '发生',
#   '生在',
#   '海里',
#   '在',
#   '海中',
#   '的',
#   '热液',
#   '里',
#   '在',
#   '海底',
#   '的',
#   '沉积',
#   '沉积物',
#   '和',
#   '岩石',
#   '里',
#   '<EOS>'],
#  ['只是', '一个', '难以', '难以置信', '置信', '的', '故事', '<EOS>'],
#  ['当',
#   '我们',
#   '找寻',
#   '寻过',
#   '过去',
#   '的',
#   '时候',
#   '我们',
#   '会',
#   '看到',
#   '这些',
#   '沉积',
#   '沉积物',
#   '和',
#   '岩石',
#   '是',
#   '地球',
#   '历史',
#   '的',
#   '一个',
#   '纪录',
#   '<EOS>'],
#  ['这个',
#   '星球',
#   '上',
#   '所有',
#   '的',
#   '事物',
#   '所有',
#   '的',
#   '都',
#   '有',
#   '自己',
#   '的',
#   '周期',
#   '和',
#   '节奏',
#   '<EOS>'],
#  ['各个', '大陆', '分离', '后会', '会合', '合拢', '<EOS>'],
#  ['海洋', '消失', '后', '又', '会', '回来', '山脉', '冰川', '都', '是', '如此', '<EOS>'],
#  ['厄尔',
#   '厄尔尼诺',
#   '现象',
#   '也',
#   '不断',
#   '出现',
#   '它',
#   '不是',
#   '一次',
#   '灾难',
#   '而是',
#   '自身',
#   '的',
#   '节奏',
#   '<EOS>'],
#  ['我们', '现在', '所', '研究', '的', '就', '像', '一部', '交响', '交响乐', '<EOS>'],
#  ['就是', '音乐', '真的', '像', '音乐', '<EOS>'],
#  ['而',
#   '我们',
#   '现在',
#   '学到',
#   '的',
#   '是',
#   '你',
#   '不能',
#   '听',
#   '了',
#   '50',
#   '亿年',
#   '年长',
#   '的',
#   '交响',
#   '交响乐',
#   '但',
#   '今天',
#   '你',
#   '突然',
#   '说',
#   '停住',
#   '我们',
#   '希望',
#   '明天',
#   '的',
#   '乐谱',
#   '和',
#   '今天',
#   '的',
#   '一样',
#   '<EOS>'],
#  ['这', '就', '很', '荒唐', '真的', '很', '荒唐', '<EOS>'],
#  ['所以',
#   '我们',
#   '现在',
#   '需要',
#   '研究',
#   '的',
#   '是',
#   '地球',
#   '的',
#   '将来',
#   '在',
#   '各个',
#   '层面',
#   '面上',
#   '上会',
#   '是',
#   '怎样',
#   '的',
#   '<EOS>'],
#  ['学习', '掌握', '它', '<EOS>'],
#  ['而', '努力', '去', '保存', '现状', '则', '是', '徒劳', '的', '<EOS>'],
#  ['而', '去', '保护', '它', '更', '难', '但', '我们', '有', '可能', '做到', '<EOS>'],
#  ['非常', '非常感谢', '感谢', '<EOS>'],
#  ['谢谢', '<EOS>'],
#  ['史蒂夫',
#   '蒂夫',
#   '凯尔',
#   '致',
#   '保加利亚',
#   '加利',
#   '加利亚',
#   '利亚',
#   '与',
#   '全世界',
#   '世界',
#   '玩耍',
#   '的',
#   '启示',
#   '<EOS>'],
#  ['在',
#   '保加利亚',
#   '加利',
#   '加利亚',
#   '利亚',
#   '首都',
#   '索菲亚',
#   '菲亚',
#   '进行',
#   '的',
#   'ted',
#   '系列',
#   '演讲',
#   '中',
#   '史蒂夫',
#   '蒂夫',
#   '凯尔',
#   '反对',
#   '影响',
#   '家乡',
#   '保加利亚',
#   '加利',
#   '加利亚',
#   '利亚',
#   '的',
#   '严重',
#   '的',
#   '文化',
#   '基因',
#   '呼唤',
#   '在',
#   '玩乐',
#   '中',
#   '振兴',
#   '经济',
#   '教育',
#   '和',
#   '社会',
#   '这',
#   '是',
#   '一段',
#   '发人',
#   '发人深省',
#   '深省',
#   '的',
#   '演讲',
#   '让',
#   '全世界',
#   '世界',
#   '正在',
#   '重塑',
#   '职场',
#   '学校',
#   '和',
#   '生活',
#   '的',
#   '人们',
#   '找到',
#   '了',
#   '共鸣',
#   '<EOS>'],
#  ['我', '今天', '来', '这里', '的', '目的', '是', '开启', '一场', '革命', '<EOS>'],
#  ['不过',
#   '在',
#   '你们',
#   '揭竿',
#   '揭竿而起',
#   '纵情',
#   '纵情歌唱',
#   '情歌',
#   '歌唱',
#   '或是',
#   '选择',
#   '幸运',
#   '幸运色',
#   '之前',
#   '让',
#   '我',
#   '先来',
#   '为',
#   '革命',
#   '下',
#   '个',
#   '定义',
#   '<EOS>'],
#  ['我',
#   '所谓',
#   '的',
#   '革命',
#   '是',
#   '指',
#   '我们',
#   '思考',
#   '和',
#   '行为',
#   '上',
#   '急剧',
#   '而',
#   '深远',
#   '的',
#   '变革',
#   '我们',
#   '思考',
#   '和',
#   '行动',
#   '的',
#   '方式',
#   '<EOS>'],
#  ['也许',
#   '你',
#   '会',
#   '问',
#   '了',
#   '史蒂夫',
#   '蒂夫',
#   '我们',
#   '为什么',
#   '什么',
#   '需要',
#   '一场',
#   '革命',
#   '呢',
#   '<EOS>'],
#  ['我们',
#   '需要',
#   '一场',
#   '革命',
#   '因为',
#   '事情',
#   '行不通',
#   '不通',
#   '通了',
#   '完全',
#   '全行',
#   '行不通',
#   '不通',
#   '通了',
#   '<EOS>'],
#  ['我',
#   '因此',
#   '而',
#   '难过',
#   '因为',
#   '我',
#   '对',
#   '行不通',
#   '不通',
#   '的',
#   '事情',
#   '情感',
#   '感到',
#   '厌烦',
#   '<EOS>'],
#  ['我', '受够', '受够了', '看着', '我们', '的', '潜能', '得不到', '不到', '完全', '施展', '<EOS>'],
#  ['我', '已', '厌倦', '我们', '处于', '最后', '一名', '的', '窘境', '<EOS>'],
#  ['而',
#   '我们',
#   '恰恰',
#   '在',
#   '很多',
#   '事情',
#   '上',
#   '都',
#   '处于',
#   '最后',
#   '一名',
#   '比如',
#   '比如说',
#   '社会',
#   '的',
#   '各个',
#   '各个方面',
#   '方面',
#   '<EOS>'],
#  ['在', '创新', '方面', '我们', '在', '全欧', '欧洲', '倒数', '倒数第', '数第一', '第一', '<EOS>'],
#  ['是',
#   '的',
#   '在',
#   '最后',
#   '在',
#   '最',
#   '底部',
#   '被',
#   '视为',
#   '最',
#   '不重',
#   '重视',
#   '创新',
#   '的',
#   '民族',
#   '<EOS>'],
#  ['在',
#   '医疗',
#   '方面',
#   '我们',
#   '也',
#   '是',
#   '最后',
#   '一名',
#   '而',
#   '医疗',
#   '又',
#   '是',
#   '幸福',
#   '幸福感',
#   '的',
#   '重要',
#   '保证',
#   '<EOS>'],
#  ['我们',
#   '不仅',
#   '在',
#   '欧盟',
#   '盟国',
#   '国家',
#   '家中',
#   '中排',
#   '排在',
#   '最后',
#   '在',
#   '整个',
#   '欧洲',
#   '都',
#   '是',
#   '垫底',
#   '<EOS>'],
#  ['而',
#   '最糟',
#   '糟糕',
#   '的',
#   '是',
#   '你们',
#   '也许',
#   '在',
#   '三个',
#   '星期',
#   '前',
#   '出版',
#   '的',
#   '经济',
#   '经济学',
#   '济学',
#   '学人',
#   '上',
#   '读到',
#   '了',
#   '<EOS>'],
#  ['就',
#   '人均',
#   'gdp',
#   '而言',
#   '我们',
#   '是',
#   '世界',
#   '上',
#   '最',
#   '悲',
#   '催',
#   '的',
#   '地方',
#   '甚至',
#   '是',
#   '整个',
#   '地球',
#   '上',
#   '最',
#   '悲',
#   '催',
#   '的',
#   '地方',
#   '<EOS>'],
#  ['这些', '只是', '社会', '层面', '我们', '再来', '来看', '看看', '教育', '<EOS>'],
#  ['在',
#   '另',
#   '一份',
#   '由',
#   '经济',
#   '经济合作与发展组织',
#   '合作',
#   '与',
#   '发展',
#   '组织',
#   '三个',
#   '星期',
#   '前',
#   '发表',
#   '的',
#   '报告',
#   '中',
#   '我们',
#   '的',
#   '排名',
#   '又',
#   '是',
#   '怎样',
#   '呢',
#   '<EOS>'],
#  ['阅读', '数学', '和', '科学', '都', '垫底', '<EOS>'],
#  ['商业', '方面', '在', '所有', '欧盟', '盟国', '国家', '家中', '<EOS>'],
#  ['我们',
#   '对',
#   '创业',
#   '创业者',
#   '业者',
#   '为',
#   '社会',
#   '带来',
#   '福利',
#   '最',
#   '不',
#   '看好',
#   '<EOS>'],
#  ['结果', '呢', '<EOS>'],
#  ['我们', '的', '自主', '主创', '创业', '百分', '百分比', '垫底', '<EOS>'],
#  ['而',
#   '我们',
#   '都',
#   '知道',
#   '小型',
#   '小型企业',
#   '企业',
#   '才',
#   '是',
#   '经济',
#   '发展',
#   '的',
#   '引擎',
#   '<EOS>'],
#  ['我们',
#   '小型',
#   '小型企业',
#   '企业',
#   '提供',
#   '最多',
#   '的',
#   '就业',
#   '岗位',
#   '在',
#   '税收',
#   '收方',
#   '方面',
#   '贡献',
#   '最高',
#   '<EOS>'],
#  ['如果', '引擎', '坏', '了', '结果', '又', '会', '如何', '呢', '<EOS>'],
#  ['在', '欧洲', '欧洲人', '人均', 'gdp', '上', '我们', '再度', '排名', '最后', '<EOS>'],
#  ['最后', '一名', '<EOS>'],
#  ['难怪',
#   '62',
#   '的',
#   '保加利亚',
#   '保加利亚人',
#   '加利',
#   '加利亚',
#   '利亚',
#   '利亚人',
#   '都',
#   '对',
#   '未来',
#   '不',
#   '抱',
#   '乐观',
#   '观心',
#   '心态',
#   '<EOS>'],
#  ['我们',
#   '生活',
#   '不幸',
#   '幸福',
#   '我们',
#   '的',
#   '教育',
#   '质量',
#   '很',
#   '差',
#   '我们',
#   '在',
#   '商业',
#   '上',
#   '也',
#   '一败涂地',
#   '<EOS>'],
#  ['这些', '都', '是', '血淋淋', '淋淋', '的', '事实', '朋友', '们', '<EOS>'],
#  ['这', '不是', '凭空', '凭空捏造', '捏造', '的', '<EOS>'],
#  ['不是', '的', '<EOS>'],
#  ['这',
#   '不是',
#   '我',
#   '针对',
#   '保加利亚',
#   '加利',
#   '加利亚',
#   '利亚',
#   '的',
#   '阴谋',
#   '这些',
#   '都',
#   '是',
#   '事实',
#   '<EOS>'],
#  ['我',
#   '认为',
#   '一切',
#   '一切都是',
#   '显而',
#   '显而易见',
#   '易见',
#   '的',
#   '我们',
#   '的',
#   '体系',
#   '已经',
#   '支离',
#   '支离破碎',
#   '破碎',
#   '<EOS>'],
#  ['我们',
#   '思考',
#   '行为',
#   '的',
#   '方式',
#   '我们',
#   '的',
#   '行为',
#   '操作',
#   '操作系统',
#   '系统',
#   '都',
#   '已',
#   '支离',
#   '支离破碎',
#   '破碎',
#   '<EOS>'],
#  ['我们',
#   '必须',
#   '须要',
#   '在',
#   '思维',
#   '与',
#   '行为',
#   '方式',
#   '上',
#   '作出',
#   '巨大',
#   '改变',
#   '让',
#   '保加利亚',
#   '加利',
#   '加利亚',
#   '利亚',
#   '变得',
#   '更好',
#   '为了',
#   '我们',
#   '自己',
#   '为了',
#   '我们',
#   '的',
#   '朋友',
#   '为了',
#   '我们',
#   '的',
#   '家人',
#   '和',
#   '未来',
#   '<EOS>'],
#  ['这', '一切', '一切都是', '怎么', '发生', '的', '呢', '<EOS>'],
#  ['我们',
#   '应该',
#   '以',
#   '积极',
#   '的',
#   '心态',
#   '看待',
#   '问题',
#   '这',
#   '一切',
#   '一切都是',
#   '怎么',
#   '发生',
#   '的',
#   '<EOS>'],
#  ['我',
#   '认为',
#   '我们',
#   '处在',
#   '最后',
#   '一名',
#   '的',
#   '原因',
#   '在于',
#   '对于',
#   '你们',
#   '中',
#   '的',
#   '某些',
#   '人',
#   '来说',
#   '这',
#   '听起',
#   '起来',
#   '可能',
#   '不可',
#   '不可思议',
#   '思议',
#   '原因',
#   '在于',
#   '我们',
#   '裹住',
#   '了',
#   '自己',
#   '的',
#   '手脚',
#   '<EOS>'],
#  ['而',
#   '我们',
#   '裹足',
#   '裹足不前',
#   '不前',
#   '的',
#   '原因',
#   '在于',
#   '我们',
#   '不重',
#   '重视',
#   '玩耍',
#   '<EOS>'],
#  ['没错', '玩耍', '<EOS>'],
#  ['如果',
#   '果在',
#   '在座',
#   '有人',
#   '已经',
#   '忘',
#   '了',
#   '玩耍',
#   '为何',
#   '何物',
#   '这',
#   '就是',
#   '玩耍',
#   '<EOS>'],
#  ['婴儿', '玩耍', '孩童', '玩耍', '成年', '成年人', '也', '玩耍', '<EOS>'],
#  ['而', '我们', '不重', '重视', '玩耍', '<EOS>'],
#  ['事实', '事实上', '我们', '摒弃', '玩耍', '<EOS>'],
#  ['我们', '从', '三个', '方面', '摒弃', '玩耍', '<EOS>'],
#  ['我们', '再', '从', '这', '三个', '方面', '来看', '<EOS>'],
#  ['社会', '45', '年', '的', '<EOS>'],
#  ['共产',
#   '共产主义',
#   '主义',
#   '社会',
#   '与',
#   '国家',
#   '利益',
#   '益高',
#   '高于',
#   '个人',
#   '个人利益',
#   '利益',
#   '不经',
#   '不经意',
#   '经意',
#   '间',
#   '创意',
#   '个人',
#   '思想',
#   '表达',
#   '和',
#   '创新',
#   '遭到',
#   '践踏',
#   '<EOS>'],
#  ['相反', '我们', '重视', '的', '是', '什么', '<EOS>'],
#  ['显而',
#   '显而易见',
#   '易见',
#   '我们',
#   '应用',
#   '知识',
#   '的',
#   '方式',
#   '受到',
#   '了',
#   '社会',
#   '与',
#   '结构',
#   '背景',
#   '的',
#   '影响',
#   '共产',
#   '共产主义',
#   '主义',
#   '要求',
#   '我们',
#   '怎么',
#   '做',
#   '<EOS>'],
#  ['要', '严肃', '<EOS>'],
#  ['非常', '非常', '严肃', '<EOS>'],
#  ['就是', '这样', '<EOS>'],
#  ['众人', '鼓掌', '严肃', '<EOS>'],
#  ['我',
#   '都',
#   '不',
#   '记得',
#   '得有',
#   '多少',
#   '多少次',
#   '我',
#   '在',
#   '公园',
#   '园里',
#   '被',
#   '人',
#   '批评',
#   '就',
#   '因为',
#   '我',
#   '让',
#   '自己',
#   '的',
#   '孩子',
#   '在',
#   '地上',
#   '玩耍',
#   '<EOS>'],
#  ['他们',
#   '不能',
#   '在',
#   '泥',
#   '保加利亚',
#   '保加利亚语',
#   '加利',
#   '加利亚',
#   '利亚',
#   '利亚语',
#   '亚语',
#   '里',
#   '玩耍',
#   '或',
#   '在',
#   '水里',
#   '玩耍',
#   '他们',
#   '会',
#   '有生',
#   '生命',
#   '生命危险',
#   '危险',
#   '<EOS>'],
#  ['一些',
#   '人',
#   '告诉',
#   '我',
#   '我们',
#   '不该',
#   '老',
#   '让',
#   '孩子',
#   '去',
#   '玩',
#   '生活',
#   '是',
#   '严肃',
#   '的',
#   '我们',
#   '必须',
#   '训练',
#   '他们',
#   '严肃',
#   '对待',
#   '生活',
#   '<EOS>'],
#  ['我们', '之中', '蔓延', '着', '一种', '严肃', '的', '文化', '基因', '<EOS>'],
#  ['这', '是', '我们', '体内', '的', '一种', '社会', '基因', '<EOS>'],
#  ['一种', '严肃', '的', '基因', '<EOS>'],
#  ['在',
#   '这',
#   '45',
#   '年',
#   '里',
#   '它',
#   '是',
#   '由',
#   '被',
#   '我',
#   '称为',
#   '爸爸',
#   '因素',
#   '的',
#   '东西',
#   '生成',
#   '的',
#   '<EOS>'],
#  ['众人', '笑', '众人', '鼓掌', '情况', '是', '这样', '的', '<EOS>'],
#  ['第一', '第一步', '一步', '女人', '说', '我', '想要', '个', '孩子', '<EOS>'],
#  ['第二', '第二步', '二步', '我们', '有', '了', '孩子', '哦', '吼', '<EOS>'],
#  ['那么', '第三', '第三步', '三步', '呢', '<EOS>'],
#  ['我',
#   '想',
#   '回去',
#   '工作',
#   '我',
#   '想进',
#   '进一步',
#   '一步',
#   '发展',
#   '事业',
#   '或者',
#   '我',
#   '只是',
#   '想',
#   '偷闲',
#   '喝喝',
#   '喝咖啡',
#   '咖啡',
#   '<EOS>'],
#  ['我', '要', '把', '孩子', '交给', '他', '爸爸', '<EOS>'],
#  ['我们',
#   '别忘了',
#   '爸爸',
#   '已经',
#   '经受',
#   '受到',
#   '了',
#   '严肃',
#   '文化',
#   '基因',
#   '45',
#   '年',
#   '的',
#   '影响',
#   '<EOS>'],
#  ['结果', '呢', '<EOS>'],
#  ['她',
#   '将',
#   '病毒',
#   '传染',
#   '传染给',
#   '了',
#   '孩子',
#   '必须',
#   '须经',
#   '经过',
#   '很',
#   '长',
#   '很',
#   '长',
#   '很',
#   '长',
#   '一段',
#   '一段时间',
#   '段时间',
#   '时间',
#   '就',
#   '像',
#   '红木',
#   '木林',
#   '这',
#   '严肃',
#   '文化',
#   '基因',
#   '才能',
#   '能够',
#   '完全',
#   '脱离',
#   '我们',
#   '的',
#   '行为',
#   '体系',
#   '<EOS>'],
#  ['接着', '呢', '<EOS>'],
#  ['它',
#   '进入',
#   '了',
#   '教育',
#   '教育领域',
#   '领域',
#   '而',
#   '我们',
#   '的',
#   '教育',
#   '制度',
#   '抱',
#   '残',
#   '守旧',
#   '在',
#   '一百',
#   '一百年',
#   '百年',
#   '年时',
#   '时间',
#   '里',
#   '几乎',
#   '没有',
#   '改变',
#   '只',
#   '注重',
#   '重生',
#   '生搬硬套',
#   '硬套',
#   '死记',
#   '死记硬背',
#   '和',
#   '墨守',
#   '墨守陈规',
#   '陈规',
#   '摒弃',
#   '自我',
#   '思想',
#   '表达',
#   '探寻',
#   '自我',
#   '批判',
#   '思维',
#   '创意',
#   '和',
#   '玩乐',
#   '<EOS>'],
#  ['这', '是', '个', '狗屎', '体系', '<EOS>'],
#  ['真实', '故事', '我', '去', '为', '孩子', '找', '学校', '<EOS>'],
#  ['我们',
#   '去',
#   '到',
#   '了',
#   '这',
#   '所',
#   '名声',
#   '名声在外',
#   '在外',
#   '的',
#   '小学',
#   '小学校',
#   '学校',
#   '他们',
#   '说',
#   '学生',
#   '每周',
#   '要',
#   '学',
#   '10',
#   '堂',
#   '数学',
#   '8',
#   '堂',
#   '科学',
#   '每天',
#   '学习',
#   '5',
#   '堂',
#   '阅读',
#   '如是',
#   '如是',
#   '<EOS>'],
#  ['我们', '问', '那么', '玩耍', '和', '休息', '的', '时间', '呢', '<EOS>'],
#  ['他们', '说', '哈', '一分', '一分钟', '分钟', '都', '没有', '<EOS>'],
#  ['众人', '笑', '我们', '说', '他', '才', '五岁', '啊', '<EOS>'],
#  ['这', '是', '造孽', '啊', '造孽', '啊', '<EOS>'],
#  ['这',
#   '的确',
#   '是',
#   '造孽',
#   '我们',
#   '的',
#   '教育',
#   '制度',
#   '度过',
#   '过于',
#   '严肃',
#   '致使',
#   '我们',
#   '生产',
#   '的',
#   '尽是',
#   '没有',
#   '思想',
#   '的',
#   '机械',
#   '机械工人',
#   '工人',
#   '把',
#   '螺丝',
#   '螺丝钉',
#   '安进',
#   '事先',
#   '钻',
#   '好',
#   '的',
#   '孔',
#   '里',
#   '<EOS>'],
#  ['很',
#   '遗憾',
#   '今天',
#   '的',
#   '问题',
#   '并',
#   '不是',
#   '工业',
#   '工业革命',
#   '革命',
#   '命中',
#   '的',
#   '问题',
#   '<EOS>'],
#  ['我们',
#   '需要',
#   '的',
#   '是',
#   '适应',
#   '适应能力',
#   '应能',
#   '能力',
#   '也',
#   '就是',
#   '学会',
#   '创造',
#   '革新',
#   '的',
#   '能力',
#   '<EOS>'],
#  ['我们', '不', '需要', '机械', '机械工人', '工人', '<EOS>'],
#  ['但',
#   '不行',
#   '啊',
#   '我们',
#   '的',
#   '文化',
#   '基因',
#   '使得',
#   '我们',
#   '不重',
#   '重视',
#   '玩乐',
#   '<EOS>'],
#  ['我们',
#   '生产',
#   '机械',
#   '机械工人',
#   '工人',
#   '还',
#   '把',
#   '他们',
#   '当作',
#   '资产',
#   '拿起',
#   '起来',
#   '再',
#   '丢弃',
#   '<EOS>'],
#  ['保加利亚',
#   '保加利亚人',
#   '加利',
#   '加利亚',
#   '利亚',
#   '利亚人',
#   '的',
#   '工作',
#   '有',
#   '哪些',
#   '品质',
#   '<EOS>'],
#  ['独断', '专横', '我', '是', '老大', '我', '说', '的', '算', '<EOS>'],
#  ['我', '是', '老板', '比', '你', '更', '懂', '<EOS>'],
#  ['不信',
#   '信任',
#   '你',
#   '明显',
#   '是',
#   '个',
#   '罪犯',
#   '我',
#   '得',
#   '装',
#   '几个',
#   '摄像',
#   '摄像头',
#   '像头',
#   '了',
#   '<EOS>'],
#  ['众人',
#   '笑',
#   '指手画脚',
#   '你',
#   '明显',
#   '是',
#   '个',
#   '白痴',
#   '我',
#   '要',
#   '设计',
#   '计成',
#   '成千',
#   '成千上百',
#   '上百',
#   '的',
#   '小步',
#   '步骤',
#   '好',
#   '让',
#   '你',
#   '遵守',
#   '这样',
#   '你',
#   '就',
#   '不会',
#   '做',
#   '错',
#   '了',
#   '<EOS>'],
#  ['他们',
#   '还',
#   '很严',
#   '严苛',
#   '不许',
#   '用',
#   '手机',
#   '不许',
#   '用笔',
#   '笔记',
#   '笔记本',
#   '笔记本电脑',
#   '电脑',
#   '不许',
#   '上网',
#   '不许',
#   '聊',
#   'qq',
#   '<EOS>'],
#  ['这样', '太', '不', '专业', '影响', '太坏', '了', '<EOS>'],
#  ['到头',
#   '到头来',
#   '这',
#   '工作',
#   '一点',
#   '成就',
#   '成就感',
#   '都',
#   '没有',
#   '你',
#   '受',
#   '人',
#   '摆布',
#   '受到',
#   '受到限制',
#   '限制',
#   '还',
#   '不',
#   '被',
#   '看重',
#   '你',
#   '得不到',
#   '不到',
#   '到任',
#   '任何',
#   '乐趣',
#   '<EOS>'],
#  ['不论',
#   '不论是',
#   '在',
#   '社会',
#   '会上',
#   '教育',
#   '上',
#   '还是',
#   '经济',
#   '上',
#   '玩耍',
#   '都',
#   '得不到',
#   '不到',
#   '重视',
#   '<EOS>'],
#  ['正因如此',
#   '如此',
#   '我们',
#   '才',
#   '落于',
#   '人',
#   '后',
#   '因为',
#   '我们',
#   '不重',
#   '重视',
#   '玩耍',
#   '<EOS>'],
#  ['你',
#   '会',
#   '反驳',
#   '说',
#   '真',
#   '荒谬',
#   '史蒂夫',
#   '蒂夫',
#   '这',
#   '想法',
#   '太',
#   '不靠',
#   '谱',
#   '了',
#   '<EOS>'],
#  ['怎么', '可能', '是因为', '因为', '玩耍', '呢', '<EOS>'],
#  ['玩耍', '太', '蠢', '了', '<EOS>'],
#  ['我们', '被', '严肃', '的', '文化', '基因', '毒害', '了', '<EOS>'],
#  ['现在', '我', '要', '对', '它', '说', '不', '<EOS>'],
#  ['我',
#   '下面',
#   '就',
#   '会',
#   '证明',
#   '给',
#   '你们',
#   '看',
#   '玩耍',
#   '就是',
#   '载体',
#   '就是',
#   '革命',
#   '能够',
#   '为',
#   '我们',
#   '所用',
#   '用来',
#   '把',
#   '保加利亚',
#   '加利',
#   '加利亚',
#   '利亚',
#   '变得',
#   '更',
#   '美好',
#   '<EOS>'],
#  ['玩耍', '我们', '的', '大脑', '是', '专为', '玩耍', '而', '设计', '的', '<EOS>'],
#  ['动物',
#   '和',
#   '人类',
#   '经过',
#   '了',
#   '几百',
#   '几百万',
#   '百万',
#   '乃至',
#   '几十',
#   '几十亿',
#   '几十亿年',
#   '十亿',
#   '亿年',
#   '的',
#   '进化',
#   '善于',
#   '玩耍',
#   '<EOS>'],
#  ['你', '知道', '吗', '<EOS>'],
#  ['进化',
#   '非常',
#   '常有',
#   '有效',
#   '将',
#   '我们',
#   '不利',
#   '的',
#   '身体',
#   '特征',
#   '淘汰',
#   '而',
#   '保留',
#   '了',
#   '有利',
#   '有利于',
#   '利于',
#   '竞争',
#   '的',
#   '特征',
#   '<EOS>'],
#  ['大自然', '自然', '可不', '不笨', '它', '让', '进化', '化为', '玩耍', '而', '服务', '<EOS>'],
#  ['例如', '在', '动物', '动物界', '中', '蚂蚁', '善于', '玩耍', '<EOS>'],
#  ['也许', '你', '还', '不知', '知道', '<EOS>'],
#  ['它们',
#   '在',
#   '玩耍',
#   '时',
#   '学习',
#   '社会',
#   '社会秩序',
#   '秩序',
#   '和',
#   '事物',
#   '的',
#   '运行',
#   '<EOS>'],
#  ['老鼠',
#   '也',
#   '玩耍',
#   '而',
#   '你们',
#   '可能',
#   '不知',
#   '知道',
#   '更好',
#   '好玩',
#   '的',
#   '老鼠',
#   '拥有',
#   '更',
#   '大',
#   '的',
#   '大脑',
#   '它们',
#   '更',
#   '善于',
#   '学习',
#   '任务',
#   '技能',
#   '<EOS>'],
#  ['我们', '都', '知道', '猫咪', '们', '好玩', '玩耍', '<EOS>'],
#  ['而',
#   '你们',
#   '可能',
#   '不知',
#   '知道',
#   '如果',
#   '不让',
#   '小猫',
#   '玩耍',
#   '那么',
#   '它们',
#   '就',
#   '无法',
#   '与其',
#   '其它',
#   '猫',
#   '交流',
#   '<EOS>'],
#  ['它们', '仍旧', '能够', '捕猎', '但', '却', '无法', '互动', '<EOS>'],
#  ['熊', '也', '玩耍', '<EOS>'],
#  ['而',
#   '你们',
#   '可能',
#   '不知',
#   '知道',
#   '更',
#   '会',
#   '玩',
#   '的',
#   '熊',
#   '能够',
#   '活得',
#   '更',
#   '久',
#   '<EOS>'],
#  ['活得', '更', '久', '的', '不是', '那些', '善于', '捕鱼', '的', '熊', '<EOS>'],
#  ['而是', '那些', '更', '会', '玩', '的', '熊', '<EOS>'],
#  ['最后',
#   '一项',
#   '非常',
#   '常有',
#   '有趣',
#   '的',
#   '研究',
#   '表明',
#   '玩耍',
#   '与',
#   '脑子',
#   '的',
#   '大小',
#   '是',
#   '有关',
#   '关联',
#   '的',
#   '<EOS>'],
#  ['玩', '得', '越多', '脑子', '越', '大', '<EOS>'],
#  ['海豚', '拥有', '很大', '的', '脑子', '善于', '玩耍', '<EOS>'],
#  ['而',
#   '你',
#   '知道',
#   '谁',
#   '的',
#   '脑子',
#   '最大',
#   '谁',
#   '才',
#   '是',
#   '最大',
#   '的',
#   '玩家',
#   '吗',
#   '<EOS>'],
#  ['答案', '是', '我们', '的', '脑子', '我们', '人类', '<EOS>'],
#  ['孩子',
#   '子玩',
#   '玩耍',
#   '我们',
#   '玩耍',
#   '每个',
#   '国家',
#   '每个',
#   '种族',
#   '每种',
#   '肤色',
#   '每种',
#   '宗教',
#   '<EOS>'],
#  ['这', '是', '我们', '的', '共同', '共同点', '同点', '玩耍', '<EOS>'],
#  ['玩耍', '并', '不', '只是', '儿童', '的', '专利', '大人', '人们', '也', '玩耍', '<EOS>'],
#  ['非常',
#   '酷',
#   '的',
#   '称谓',
#   '童心',
#   '童心未泯',
#   '未泯',
#   '少年',
#   '好玩',
#   '的',
#   '天性',
#   '在',
#   '成年',
#   '成年人',
#   '内心',
#   '的',
#   '延续',
#   '<EOS>'],
#  ['谁', '最', '童心', '童心未泯', '未泯', '<EOS>'],
#  ['人类', '我们', '玩', '运动', '<EOS>'],
#  ['为',
#   '娱乐',
#   '或',
#   '作为',
#   '奥林匹',
#   '奥林匹克',
#   '奥林匹克运动',
#   '运动',
#   '运动员',
#   '动员',
#   '或',
#   '作为',
#   '职业',
#   '选手',
#   '<EOS>'],
#  ['我们', '玩乐', '乐器', '<EOS>'],
#  ['我们', '跳舞', '亲吻', '歌唱', '我们', '追逐', '打闹', '<EOS>'],
#  ['我们', '天生', '生就', '会', '玩耍', '从', '生', '到', '老', '<EOS>'],
#  ['我们', '天生', '就', '喜欢', '一直', '玩', '不停', '地', '玩', '<EOS>'],
#  ['这', '是', '很大', '的', '优势', '<EOS>'],
#  ['对', '动物', '有利', '对', '人类', '也', '有利', '<EOS>'],
#  ['例如',
#   '研究',
#   '表明',
#   '玩耍',
#   '能够',
#   '刺激',
#   '扁桃',
#   '扁桃腺',
#   '情绪',
#   '控制',
#   '控制区',
#   '的',
#   '神经',
#   '增长',
#   '<EOS>'],
#  ['玩耍',
#   '还',
#   '能够',
#   '促进',
#   '进前',
#   '前脑',
#   '皮层',
#   '的',
#   '发展',
#   '这',
#   '正是',
#   '意识',
#   '形成',
#   '的',
#   '区域',
#   '<EOS>'],
#  ['那么', '结果', '呢', '<EOS>'],
#  ['我们', '玩', '得', '越多', '我们', '的', '情绪', '成熟', '成熟度', '就越', '高', '<EOS>'],
#  ['我们', '玩', '得', '越多', '我们', '的', '决策', '能力', '越', '强', '<EOS>'],
#  ['这些', '都', '是', '事实', '<EOS>'],
#  ['不是', '小说', '童话', '或', '瞎掰', '这', '是', '冷冰冰', '冰冰', '的', '科学', '<EOS>'],
#  ['这些', '是', '玩耍', '带来', '的', '好处', '<EOS>'],
#  ['就',
#   '像',
#   '行走',
#   '说话',
#   '或',
#   '睁眼',
#   '眼看',
#   '世界',
#   '一样',
#   '玩耍',
#   '是',
#   '我们',
#   '与生俱来',
#   '的',
#   '权利',
#   '<EOS>'],
#  ['而',
#   '如果',
#   '不让',
#   '自己',
#   '玩耍',
#   '我们',
#   '的',
#   '身体',
#   '就',
#   '会',
#   '像',
#   '失去',
#   '了',
#   '其它',
#   '与生俱来',
#   '的',
#   '权利',
#   '一样',
#   '变得',
#   '残缺',
#   '残缺不全',
#   '<EOS>'],
#  ['我们', '束缚', '了', '自己', '的', '手脚', '<EOS>'],
#  ['做',
#   '个',
#   '简短',
#   '的',
#   '练习',
#   '你们',
#   '闭上眼',
#   '闭上眼睛',
#   '上眼',
#   '眼睛',
#   '试',
#   '着想',
#   '想象',
#   '一个',
#   '没有',
#   '玩乐',
#   '的',
#   '世界',
#   '<EOS>'],
#  ['想象',
#   '一个',
#   '没有',
#   '剧院',
#   '没有',
#   '艺术',
#   '没有',
#   '歌曲',
#   '没有',
#   '舞蹈',
#   '没有',
#   '足球',
#   '没有',
#   '橄榄',
#   '橄榄球',
#   '没有',
#   '笑声',
#   '的',
#   '世界',
#   '<EOS>'],
#  ['这', '是', '一个', '什么', '什么样', '的', '世界', '<EOS>'],
#  ['相当', '惨白', '<EOS>'],
#  ['相当', '悲', '催', '<EOS>'],
#  ['现在', '想象', '你', '的', '工作', '场所', '<EOS>'],
#  ['那里', '有趣', '吗', '好玩', '吗', '<EOS>'],
#  ['或', '想象', '你', '朋友', '的', '工作', '场所', '我们', '做', '换位', '思考', '<EOS>'],
#  ['那里', '有趣', '吗', '好玩', '吗', '<EOS>'],
#  ['还是',
#   '没意思',
#   '意思',
#   '机械',
#   '机械化',
#   '控制',
#   '欲',
#   '强',
#   '诸多',
#   '限制',
#   '没有',
#   '信任',
#   '没有',
#   '有成',
#   '成就',
#   '成就感',
#   '<EOS>'],
#  ['我们', '总以为', '以为', '工作', '与', '玩乐', '是', '水火', '水火不容', '不容', '的', '<EOS>'],
#  ['我们', '甚至', '会', '为', '边', '工作', '边玩', '玩耍', '而', '感到', '羞愧', '<EOS>'],
#  ['哦',
#   '我',
#   '的',
#   '同事',
#   '看见',
#   '我',
#   '在',
#   '笑',
#   '我',
#   '肯定',
#   '没',
#   '好好',
#   '工作',
#   '或者',
#   '哦',
#   '我',
#   '必须',
#   '偷偷',
#   '偷偷摸摸',
#   '偷摸',
#   '摸摸',
#   '地',
#   '免得',
#   '让',
#   '老板',
#   '看见',
#   '<EOS>'],
#  ['他', '会', '认为', '我', '没有', '卖力', '工作', '<EOS>'],
#  ['告诉', '你', '个', '消息', '我们', '把', '这', '想', '反', '了', '<EOS>'],
#  ['玩乐', '的', '反义', '反义词', '并', '不是', '工作', '<EOS>'],
#  ['玩乐', '的', '反义', '反义词', '是', '压迫', '压迫', '<EOS>'],
#  ['事实', '事实上', '玩耍', '能够', '改善', '我们', '的', '工作', '<EOS>'],
#  ['玩耍',
#   '能够',
#   '给',
#   '人类',
#   '与',
#   '动物',
#   '带来',
#   '好处',
#   '它',
#   '同样',
#   '可以',
#   '以为',
#   '工作',
#   '造福',
#   '<EOS>'],
#  ['比如', '它', '能', '促进', '创新', '创新能力', '能力', '<EOS>'],
#  ['让', '我们', '更', '敢于', '做出', '改变', '<EOS>'],
#  ['提高', '我们', '的', '学习', '能力', '<EOS>'],
#  ['让',
#   '我们',
#   '更',
#   '有',
#   '目标',
#   '和',
#   '掌控',
#   '力',
#   '这',
#   '是',
#   '玩耍',
#   '提高',
#   '生产',
#   '生产力',
#   '的',
#   '两个',
#   '关键',
#   '动因',
#   '<EOS>'],
#  ['不要',
#   '急',
#   '着',
#   '认为',
#   '玩耍',
#   '就是',
#   '不严',
#   '严肃',
#   '玩耍',
#   '并',
#   '不意',
#   '意味',
#   '意味着',
#   '不正',
#   '不正经',
#   '正经',
#   '<EOS>'],
#  ['正如',
#   '一位',
#   '职业',
#   '运动',
#   '运动员',
#   '动员',
#   '喜爱',
#   '滑雪',
#   '他',
#   '的',
#   '态度',
#   '是',
#   '严肃',
#   '的',
#   '但',
#   '他',
#   '热爱',
#   '滑雪',
#   '<EOS>'],
#  ['他', '感到', '愉快', '他', '玩', '得', '酣畅', '酣畅淋漓', '淋漓', '<EOS>'],
#  ['一位',
#   '医生',
#   '可能',
#   '很严',
#   '严肃',
#   '但',
#   '欢笑',
#   '也',
#   '是',
#   '一种',
#   '灵丹',
#   '灵丹妙药',
#   '妙药',
#   '<EOS>'],
#  ['我们', '都', '想', '反', '了', '<EOS>'],
#  ['我们', '不应', '应该', '感到', '羞愧', '<EOS>'],
#  ['我们', '应为', '玩耍', '而', '欢庆', '<EOS>'],
#  ['举', '一个', '企业', '的', '例子', '<EOS>'],
#  ['联邦', '联邦快递', '快递', '口号', '很', '简练', '人', '服务', '利润', '<EOS>'],
#  ['如果',
#   '你',
#   '人性',
#   '性地',
#   '对待',
#   '待人',
#   '好好',
#   '对待',
#   '他们',
#   '他们',
#   '就',
#   '会',
#   '更',
#   '开心',
#   '更',
#   '有成',
#   '成就',
#   '成就感',
#   '他们',
#   '做事',
#   '就',
#   '更',
#   '有',
#   '掌控',
#   '力',
#   '和',
#   '目的',
#   '目的性',
#   '<EOS>'],
#  ['结果',
#   '呢',
#   '他们',
#   '提供',
#   '更优',
#   '优质',
#   '的',
#   '服务',
#   '不是',
#   '更',
#   '差',
#   '而是',
#   '更优',
#   '<EOS>'],
#  ['当',
#   '顾客',
#   '打电话',
#   '电话',
#   '要求',
#   '服务',
#   '和',
#   '他们',
#   '打交道',
#   '交道',
#   '的',
#   '是',
#   '有',
#   '主见',
#   '有成',
#   '成就',
#   '成就感',
#   '的',
#   '快乐',
#   '人群',
#   '这些',
#   '顾客',
#   '的',
#   '感觉',
#   '如何',
#   '他们',
#   '感觉',
#   '棒极了',
#   '极了',
#   '<EOS>'],
#  ['而', '这些', '感觉', '感觉良好', '良好', '的', '顾客', '会', '怎么', '做', '呢', '<EOS>'],
#  ['他们',
#   '会',
#   '购买',
#   '更多',
#   '的',
#   '服务',
#   '并',
#   '向',
#   '自己',
#   '的',
#   '朋友',
#   '推荐',
#   '于是',
#   '更多',
#   '多利',
#   '利润',
#   '产生',
#   '了',
#   '<EOS>'],
#  ['这', '就是', '人', '服务', '利润', '<EOS>'],
#  ['玩耍', '提高', '了', '而', '不是', '减低', '了', '生产', '生产力', '<EOS>'],
#  ['你',
#   '可能',
#   '会',
#   '说',
#   '切',
#   '这',
#   '一套',
#   '在',
#   '美国',
#   '的',
#   '联邦',
#   '联邦快递',
#   '快递',
#   '行得通',
#   '这',
#   '在',
#   '保加利亚',
#   '加利',
#   '加利亚',
#   '利亚',
#   '就',
#   '不灵',
#   '了',
#   '<EOS>'],
#  ['没门', '我们', '不一', '一样', '<EOS>'],
#  ['朋友',
#   '们',
#   '这',
#   '在',
#   '保加利亚',
#   '加利',
#   '加利亚',
#   '利亚',
#   '是',
#   '行得通',
#   '的',
#   '原因',
#   '有',
#   '二',
#   '<EOS>'],
#  ['第一', '玩耍', '是', '世界', '通用', '的', '<EOS>'],
#  ['只要',
#   '摒弃',
#   '了',
#   '原有',
#   '的',
#   '严肃',
#   '文化',
#   '基因',
#   '我们',
#   '保加利亚',
#   '保加利亚人',
#   '加利',
#   '加利亚',
#   '利亚',
#   '利亚人',
#   '玩耍',
#   '就是',
#   '无可',
#   '无可厚非',
#   '厚非',
#   '的',
#   '<EOS>'],
#  ['第二', '我', '尝试', '试过', '了', '我', '在', 'sciant', '尝试', '试过', '了', '<EOS>'],
#  ['我', '刚', '到', '的', '时候', '我们', '没有', '一个', '开心', '的', '顾客', '<EOS>'],
#  ['没有', '一个', '顾客', '推荐', '我们', '<EOS>'],
#  ['我', '一个', '一个个', '个个', '都', '问', '过', '了', '<EOS>'],
#  ['而', '我们', '有边', '边际', '利润', '我', '认为', '有', '<EOS>'],
#  ['我们', '有边', '边际', '利润', '还有', '不开', '开心', '的', '利益', '相关', '方', '<EOS>'],
#  ['通过',
#   '一些',
#   '基本',
#   '的',
#   '改变',
#   '包括',
#   '提高',
#   '透明',
#   '透明度',
#   '明度',
#   '鼓励',
#   '自主',
#   '决策',
#   '协同',
#   '合作',
#   '鼓励',
#   '合作',
#   '而',
#   '不是',
#   '机械',
#   '机械化',
#   '应',
#   '注重',
#   '结果',
#   '<EOS>'],
#  ['我',
#   '不管',
#   '你',
#   '是不是',
#   '不是',
#   '一大',
#   '一大早',
#   '大早',
#   '早来',
#   '上班',
#   '也',
#   '不在',
#   '不在乎',
#   '在乎',
#   '你',
#   '什么',
#   '时候',
#   '下班',
#   '<EOS>'],
#  ['我',
#   '只',
#   '关心',
#   '你',
#   '的',
#   '客户',
#   '和',
#   '团队',
#   '是否',
#   '开心',
#   '而',
#   '你',
#   '是否',
#   '为此',
#   '做好',
#   '了',
#   '安排',
#   '<EOS>'],
#  ['你', '是否', '九点', '九点钟', '点钟', '来', '上班', '与我何干', '何干', '呢', '<EOS>'],
#  ['要', '让', '工作', '更', '有意', '有意思', '意思', '<EOS>'],
#  ['通过',
#   '过活',
#   '活跃',
#   '并',
#   '创造',
#   '良好',
#   '好气',
#   '气氛',
#   '我们',
#   '在',
#   '短短',
#   '三年',
#   '年内',
#   '改变',
#   '了',
#   'sciant',
#   '似乎',
#   '时间',
#   '不',
#   '短',
#   '但',
#   '变革',
#   '的',
#   '进行',
#   '急',
#   '不得',
#   '每',
#   '一位',
#   '顾客',
#   '从',
#   '零',
#   '到',
#   '所有',
#   '顾客',
#   '都',
#   '推崇',
#   '我们',
#   '利润',
#   '超过',
#   '了',
#   '行业',
#   '平均',
#   '平均水平',
#   '水平',
#   '让利',
#   '利益',
#   '相关',
#   '方',
#   '感到',
#   '开心',
#   '<EOS>'],
#  ['你', '可能', '会', '说', '你', '怎么', '知道', '他们', '开心', '呢', '<EOS>'],
#  ['因为',
#   '每',
#   '一年',
#   '我们',
#   '都',
#   '进入',
#   '了',
#   '小型',
#   '小型企业',
#   '企业',
#   '最佳',
#   '最佳雇主',
#   '雇主',
#   '排行',
#   '排行榜',
#   '<EOS>'],
#  ['这',
#   '是',
#   '由',
#   '员工',
#   '在',
#   '不',
#   '记名',
#   '问卷',
#   '卷上',
#   '的',
#   '独立',
#   '分析',
#   '得出',
#   '的',
#   '<EOS>'],
#  ['它', '在', '保加利亚', '加利', '加利亚', '利亚', '是', '可行', '的', '<EOS>'],
#  ['除了', '我们', '对', '玩耍', '的', '偏见', '没有', '什么', '能够', '阻止', '我们', '<EOS>'],
#  ['作为',
#   '结尾',
#   '我们',
#   '可以',
#   '通过',
#   '几个',
#   '步骤',
#   '通过',
#   '玩耍',
#   '来',
#   '促成',
#   '这场',
#   '革命',
#   '<EOS>'],
#  ['首先', '你们', '必须', '相信', '我', '<EOS>'],
#  ['如果', '你们', '不信', '我', '那', '就', '请', '回家', '后', '再好', '好好', '想想', '<EOS>'],
#  ['第二',
#   '如果',
#   '你',
#   '没有',
#   '玩耍',
#   '的',
#   '意兴',
#   '你',
#   '需要',
#   '重新',
#   '新发',
#   '发现',
#   '玩耍',
#   '的',
#   '乐趣',
#   '<EOS>'],
#  ['你',
#   '儿时',
#   '所',
#   '享受',
#   '的',
#   '快乐',
#   '或是',
#   '你',
#   '六个',
#   '六个月',
#   '月前',
#   '前所',
#   '享受',
#   '的',
#   '快乐',
#   '而',
#   '现在',
#   '你',
#   '因为',
#   '升',
#   '了',
#   '职',
#   '而',
#   '享受',
#   '不到',
#   '因为',
#   '你',
#   '认为',
#   '自己',
#   '应该',
#   '严肃',
#   '些',
#   '重新',
#   '新发',
#   '发现',
#   '你',
#   '的',
#   '玩乐',
#   '乐吧',
#   '<EOS>'],
#  ['不管',
#   '是',
#   '骑',
#   '山地',
#   '自行',
#   '自行车',
#   '行车',
#   '阅读',
#   '或',
#   '玩游',
#   '玩游戏',
#   '游戏',
#   '<EOS>'],
#  ['重新',
#   '新发',
#   '发现',
#   '其中',
#   '中乐',
#   '乐趣',
#   '吧',
#   '你',
#   '就是',
#   '先锋',
#   '是',
#   '创新',
#   '的',
#   '先锋',
#   '思想',
#   '的',
#   '先锋',
#   '<EOS>'],
#  ['你们',
#   '要',
#   '回到',
#   '办公',
#   '办公室',
#   '公室',
#   '或',
#   '告诉',
#   '你们',
#   '的',
#   '朋友',
#   '为',
#   '玩耍',
#   '的',
#   '革命',
#   '点燃',
#   '星星',
#   '星星之火',
#   '<EOS>'],
#  ['你们', '必须', '这么', '做', '如果', '你', '你', '的', '同事', '员工', '感觉', '不到', '<EOS>'],
#  ['你', '就', '必须', '回去', '说', '嘿', '我', '相信', '你', '<EOS>'],
#  ['多', '新鲜', '啊', '我', '聘用', '你', '我', '就', '该', '相信', '你', '<EOS>'],
#  ['我',
#   '让',
#   '你',
#   '做主',
#   '我',
#   '把',
#   '权力',
#   '交给',
#   '你',
#   '我',
#   '要',
#   '把',
#   '权力',
#   '交给',
#   '最',
#   '基层',
#   '而',
#   '不是',
#   '最高',
#   '最高层',
#   '高层',
#   '的',
#   '人员',
#   '<EOS>'],
#  ['我', '要', '鼓励', '有', '建设', '建设性', '的', '批评', '<EOS>'],
#  ['我', '要', '让', '你们', '挑战', '挑战权', '权威', '<EOS>'],
#  ['只有',
#   '挑战',
#   '我们',
#   '一贯',
#   '做事',
#   '的',
#   '方法',
#   '我们',
#   '才能',
#   '从',
#   '抱',
#   '残',
#   '守旧',
#   '中',
#   '解脱',
#   '脱出',
#   '出来',
#   '才能',
#   '想出',
#   '出具',
#   '具有',
#   '创意',
#   '的',
#   '办法',
#   '解决',
#   '今天',
#   '的',
#   '问题',
#   '<EOS>'],
#  ['作为', '领导', '领导人', '我们', '不可', '可能', '总是', '对', '的', '<EOS>'],
#  ['我们', '要', '根除', '恐惧', '<EOS>'],
#  ['恐惧', '是', '玩乐', '的', '天敌', '<EOS>'],
#  ['我们', '要', '采取', '采取行动', '行动', '要', '消除', '严格', '限制', '<EOS>'],
#  ['让', '他们', '用', '手机', '打私', '私人', '电话', '随', '他们', '吧', '<EOS>'],
#  ['让', '他们', '上网', '<EOS>'],
#  ['让', '他们', '网聊', '<EOS>'],
#  ['让', '他们', '吃', '个', '长长', '长长的', '午餐', '<EOS>'],
#  ['午餐', '就是', '工作', '的', '休息', '休息时间', '时间', '<EOS>'],
#  ['你',
#   '可以',
#   '在',
#   '午餐',
#   '时',
#   '出去',
#   '走走',
#   '给',
#   '大脑',
#   '充电',
#   '与',
#   '友人',
#   '相约',
#   '来',
#   '瓶',
#   '啤酒',
#   '点',
#   '几道',
#   '小菜',
#   '谈笑',
#   '谈笑风生',
#   '交流',
#   '一下',
#   '想法',
#   '你',
#   '可能',
#   '会',
#   '获得',
#   '之前',
#   '没有',
#   '过',
#   '的',
#   '点子',
#   '<EOS>'],
#  ['放手',
#   '让',
#   '他们',
#   '去',
#   '做',
#   '给',
#   '他们',
#   '一些',
#   '自由',
#   '总的说',
#   '就是',
#   '让',
#   '他们',
#   '去',
#   '玩',
#   '让',
#   '他们',
#   '在职',
#   '职场',
#   '场上',
#   '玩乐',
#   '<EOS>'],
#  ['我们',
#   '在职',
#   '职场',
#   '场上',
#   '投入',
#   '了',
#   '那么',
#   '多',
#   '时间',
#   '工作',
#   '应该',
#   '该是',
#   '啥',
#   '一件',
#   '苦差',
#   '苦差事',
#   '差事',
#   '二十',
#   '二十年',
#   '十年',
#   '就',
#   '这么',
#   '过去',
#   '了',
#   '你',
#   '一',
#   '睁眼',
#   '说',
#   '就',
#   '这样',
#   '啦',
#   '<EOS>'],
#  ['就', '这么', '完', '了', '<EOS>'],
#  ['没门', '<EOS>'],
#  ['众人',
#   '笑',
#   '总而言之',
#   '而言',
#   '之',
#   '我们',
#   '需要',
#   '作出',
#   '巨大',
#   '的',
#   '变革',
#   '改变',
#   '我们',
#   '思考',
#   '和',
#   '行动',
#   '的',
#   '方式',
#   '我们',
#   '不',
#   '需要',
#   '工人',
#   '的',
#   '革命',
#   '<EOS>'],
#  ['我们', '不', '需要', '工人', '革命', '<EOS>'],
#  ['我们', '需要', '的', '是', '玩家', '的', '崛起', '<EOS>'],
#  ['我们', '需要', '的', '是', '玩家', '的', '崛起', '<EOS>'],
#  ['我们', '需要', '的', '是', '玩家', '的', '崛起', '<EOS>'],
#  ['说真的', '真的', '我们', '必须', '团结', '团结一致', '一致', '<EOS>'],
#  ['今天', '就是', '崛起', '之日', '<EOS>'],
#  ['我们', '需要', '做', '的', '是', '煽起', '革命', '之', '火', '<EOS>'],
#  ['你们',
#   '要',
#   '将',
#   '想法',
#   '和',
#   '成功',
#   '的',
#   '故事',
#   '四处',
#   '四处奔走',
#   '奔走',
#   '奔走相告',
#   '相告',
#   '如何',
#   '重塑',
#   '我们',
#   '的',
#   '生活',
#   '我们',
#   '的',
#   '学校',
#   '如何',
#   '将',
#   '工作',
#   '与',
#   '玩乐',
#   '相结合',
#   '结合',
#   '玩乐',
#   '如何',
#   '促成',
#   '目的',
#   '目的性',
#   '和',
#   '成就',
#   '成就感',
#   '玩乐',
#   '如何',
#   '推动',
#   '创新',
#   '和',
#   '生产',
#   '生产力',
#   '最重',
#   '重要',
#   '的',
#   '是',
#   '玩乐',
#   '如何',
#   '让',
#   '一切',
#   '切变',
#   '变得',
#   '得有',
#   '有意',
#   '意义',
#   '<EOS>'],
#  ['孤掌难鸣',
#   '我们',
#   '必须',
#   '协同',
#   '合作',
#   '如果',
#   '我们',
#   '携手',
#   '携手并肩',
#   '并肩',
#   '将',
#   '关于',
#   '玩耍',
#   '的',
#   '思想',
#   '传播',
#   '开来',
#   '我们',
#   '就',
#   '能',
#   '把',
#   '保加利亚',
#   '加利',
#   '加利亚',
#   '利亚',
#   '变得',
#   '更加',
#   '加美',
#   '美好',
#   '<EOS>'],
#  ['感谢', '大家', '<EOS>'],
#  ['众人', '鼓掌', '<EOS>'],
#  ['andreas', 'schleicher', '利用', '数据', '创建', '更好', '的', '学校', '<EOS>'],
#  ['我们',
#   '如何',
#   '衡量',
#   '什么',
#   '使',
#   '一个',
#   '学校',
#   '系统',
#   '成功',
#   '呢',
#   'andreas',
#   'schleicheru',
#   '将',
#   '为',
#   '我们',
#   '解读',
#   'pisa',
#   '测试',
#   '一种',
#   '将',
#   '国际',
#   '教育',
#   '教育系',
#   '系统',
#   '进行',
#   '排名',
#   '然后',
#   '再',
#   '用',
#   '其',
#   '排位',
#   '位数',
#   '数据',
#   '来',
#   '帮助',
#   '助学',
#   '学校',
#   '校改',
#   '改进',
#   '教学',
#   '的',
#   '评价',
#   '方法',
#   '再',
#   '使用',
#   '同样',
#   '的',
#   '数据',
#   '帮助',
#   '助学',
#   '学校',
#   '校改',
#   '改进',
#   '了解',
#   '你',
#   '的',
#   '国家',
#   '的',
#   '教育',
#   '体系',
#   '的',
#   '排位',
#   '并',
#   '探索',
#   '是',
#   '什么',
#   '因素',
#   '使得',
#   '一',
#   '国',
#   '的',
#   '教育',
#   '体系',
#   '远',
#   '优于',
#   '别国',
#   '<EOS>'],
#  ['学校',
#   '教育',
#   '的',
#   '全方位',
#   '方位',
#   '开放',
#   '目前',
#   '还是',
#   '一件',
#   '可望',
#   '可望而不可及',
#   '不可',
#   '及',
#   '的',
#   '事',
#   '<EOS>'],
#  ['我们',
#   '历尽',
#   '历尽艰辛',
#   '艰辛',
#   '才',
#   '弄',
#   '明白',
#   '学习',
#   '不是',
#   '一个',
#   '在',
#   '哪',
#   '学',
#   '的',
#   '问题',
#   '而是',
#   '一项',
# ...
#   '的',
#   '但',
#   '你',
#   '知道',
#   '有时',
#   '时人',
#   '人们',
#   '想到',
#   '我们',
#   '第一',
#   '第一个',
#   '一个',
#   '念头',
#   '就是',
#   '生物',
#   '安全',
#   '以及',
#   '及其',
#   '其它',
#   '黑暗',
#   '的',
#   '方面',
#   '<EOS>'],
#  ['我', '不会', '会试', '着', '去', '打消', '这些', '顾虑', '<EOS>'],
#  ['因为',
#   '任何',
#   '强大',
#   '科技',
#   '的',
#   '作用',
#   '生来',
#   '都',
#   '是',
#   '两面',
#   '两面性',
#   '的',
#   '如果',
#   '你',
#   '对',
#   '合成',
#   '生物',
#   '生物学',
#   '纳米',
#   '生物',
#   '生物科技',
#   '科技',
#   '这种',
#   '东西',
#   '真正',
#   '感兴',
#   '感兴趣',
#   '兴趣',
#   '就',
#   '必须',
#   '同时',
#   '关注',
#   '相关',
#   '业余',
#   '业余爱好',
#   '爱好',
#   '群体',
#   '和',
#   '专业',
#   '专业人士',
#   '人士',
#   '因为',
#   '他们',
#   '有',
#   '更好',
#   '的',
#   '基础',
#   '基础设施',
#   '设施',
#   '更好',
#   '的',
#   '设备',
#   '也',
#   '能',
#   '直接',
#   '接接',
#   '接触',
#   '病原',
#   '病原体',
#   '原体',
#   '<EOS>'],
#  ['联合',
#   '联合国',
#   '就是',
#   '这样',
#   '做',
#   '的',
#   '最近',
#   '他们',
#   '就',
#   '整个',
#   '生物',
#   '生物科技',
#   '科技',
#   '科技领域',
#   '领域',
#   '发布',
#   '了',
#   '一份',
#   '报告',
#   '并得',
#   '得出',
#   '得出结论',
#   '结论',
#   '这种',
#   '科技',
#   '的',
#   '影响',
#   '积极',
#   '积极意义',
#   '极意',
#   '意义',
#   '要',
#   '远远',
#   '远大',
#   '远大于',
#   '大于',
#   '消极',
#   '极意',
#   '意义',
#   '他们',
#   '还',
#   '特意',
#   '强调',
#   '了',
#   'diy',
#   '生物',
#   '生物学',
#   '这',
#   '一',
#   '领域',
#   '指出',
#   '媒体',
#   '一直',
#   '有',
#   '一种',
#   '高估',
#   '我们',
#   '的',
#   '能力',
#   '而',
#   '低估',
#   '我们',
#   '的',
#   '道德',
#   '道德水准',
#   '水准',
#   '的',
#   '倾向',
#   '<EOS>'],
#  ['事实',
#   '事实上',
#   '来自',
#   '世界',
#   '世界各地',
#   '各地',
#   '包括',
#   '美洲',
#   '欧洲',
#   '的',
#   'diy',
#   '生物',
#   '生物学',
#   '生物学家',
#   '学家',
#   '去年',
#   '已经',
#   '在',
#   '去年',
#   '共同',
#   '敲定',
#   '了',
#   '我们',
#   '的',
#   '道德',
#   '准则',
#   '<EOS>'],
#  ['而', '传统', '科学', '却', '没有', '做到', '这', '一点', '<EOS>'],
#  ['我们', '遵循', '国家', '和', '地区', '的', '规定', '<EOS>'],
#  ['合理',
#   '处置',
#   '废料',
#   '垃圾',
#   '遵守',
#   '安全',
#   '细则',
#   '不使',
#   '使用',
#   '病原',
#   '病原体',
#   '原体',
#   '<EOS>'],
#  ['如果',
#   '你',
#   '使用',
#   '了',
#   '病原',
#   '病原体',
#   '原体',
#   '你',
#   '就',
#   '不是',
#   '生物',
#   '黑客',
#   '社区',
#   '的',
#   '一份',
#   '份子',
#   '你',
#   '就是',
#   '生物',
#   '恐怖',
#   '恐怖分子',
#   '分子',
#   '社区',
#   '的',
#   '成员',
#   '抱歉',
#   '<EOS>'],
#  ['有时',
#   '有时候',
#   '时候',
#   '有人',
#   '问',
#   '我',
#   '那么',
#   '万一',
#   '一发',
#   '发生',
#   '生事',
#   '事故',
#   '怎么',
#   '怎么办',
#   '<EOS>'],
#  ['我',
#   '可以',
#   '这样',
#   '说',
#   '使用',
#   '常规',
#   '安全',
#   '的',
#   '生物',
#   '生物体',
#   '物体',
#   '事故',
#   '发生',
#   '的',
#   '几率',
#   '就',
#   '像',
#   '不小',
#   '小心',
#   '创造',
#   '造出',
#   '某种',
#   '超级',
#   '细菌',
#   '一样',
#   '就',
#   '同一',
#   '一场',
#   '暴雪',
#   '降临',
#   '在',
#   '沙',
#   '哈拉',
#   '沙漠',
#   '正中',
#   '一样',
#   '小',
#   '<EOS>'],
#  ['它',
#   '确实',
#   '实有',
#   '可能',
#   '发生',
#   '但',
#   '我',
#   '不',
#   '打算',
#   '为',
#   '这种',
#   '事',
#   '担',
#   '扰',
#   '<EOS>'],
#  ['我', '实际', '实际上', '准备', '冒', '另', '一种', '风险', '<EOS>'],
#  ['我', '签署', '了', '一个', '叫', 'personal', 'genome', '的', '项目', '<EOS>'],
#  ['它',
#   '是',
#   '一项',
#   '在',
#   '哈佛',
#   '哈佛大学',
#   '大学',
#   '进行',
#   '的',
#   '项目',
#   '研究',
#   '结束',
#   '后',
#   '我',
#   '所有',
#   '的',
#   '基因',
#   '序列',
#   '医疗',
#   '信息',
#   '个人',
#   '个人身份',
#   '人身',
#   '身份',
#   '都',
#   '会',
#   '由',
#   '他们',
#   '公布',
#   '在',
#   '网络',
#   '上',
#   '所有',
#   '所有人',
#   '有人',
#   '都',
#   '能',
#   '看到',
#   '<EOS>'],
#  ['在',
#   '知情',
#   '同意',
#   '环节',
#   '节时',
#   '他们',
#   '谈论',
#   '了',
#   '很多',
#   '可能',
#   '遇到',
#   '的',
#   '风险',
#   '<EOS>'],
#  ['我',
#   '最',
#   '喜欢',
#   '的',
#   '一个',
#   '是',
#   '有人',
#   '下载',
#   '了',
#   '我们',
#   '基因',
#   '序列',
#   '回到',
#   '实验',
#   '实验室',
#   '合成',
#   '一个',
#   '假',
#   'ellen',
#   '的',
#   'dna',
#   '然后',
#   '后放',
#   '放在',
#   '一个',
#   '犯罪',
#   '犯罪现场',
#   '现场',
#   '场里',
#   '<EOS>'],
#  ['但',
#   '像',
#   'diy',
#   '生物',
#   '生物学',
#   '一样',
#   '我',
#   '相信',
#   '它',
#   '正面',
#   '的',
#   '结果',
#   '以及',
#   '为',
#   '带来',
#   '研究',
#   '的',
#   '益处',
#   '还是',
#   '超过',
#   '了',
#   '风险',
#   '<EOS>'],
#  ['也许',
#   '你',
#   '会',
#   '自问',
#   '在',
#   '生物',
#   '实验',
#   '实验室',
#   '我',
#   '都',
#   '能',
#   '做',
#   '些',
#   '什么',
#   '<EOS>'],
#  ['不久',
#   '不久前',
#   '类似',
#   '似的',
#   '问题',
#   '也',
#   '有',
#   '过',
#   '人们',
#   '用电',
#   '电脑',
#   '都',
#   '能',
#   '做',
#   '些',
#   '什么',
#   '<EOS>'],
#  ['所以', '这', '仅仅', '是', '个', '开始', '<EOS>'],
#  ['我们', '只是', '瞥见', '了', 'dna', '的', '冰山', '冰山一角', '一角', '<EOS>'],
#  ['让', '我', '告诉', '你', '你', '现在', '能', '做', '些', '什么', '<EOS>'],
#  ['一位',
#   '德国',
#   '的',
#   '生物',
#   '黑客',
#   '也',
#   '是',
#   '个',
#   '记者',
#   '他',
#   '想',
#   '知道',
#   '谁家',
#   '的',
#   '狗',
#   '在',
#   '他家',
#   '附近',
#   '的',
#   '街道',
#   '上',
#   '留下',
#   '了',
#   '小礼',
#   '礼物',
#   '<EOS>'],
#  ['你们',
#   '猜',
#   '对了',
#   '他',
#   '向',
#   '所有',
#   '邻居',
#   '邻居家',
#   '居家',
#   '的',
#   '狗',
#   '扔',
#   '网球',
#   '分析',
#   '唾液',
#   '成分',
#   '找到',
#   '了',
#   '那',
#   '只',
#   '狗',
#   '并',
#   '向',
#   '主人',
#   '说明',
#   '了',
#   '情况',
#   '<EOS>'],
#  ['我', '在', '我家', '后院', '发现', '了', '一只', '入侵', '物种', '<EOS>'],
#  ['看上', '看上去', '上去', '像', '只', '瓢虫', '是', '吗', '<EOS>'],
#  ['其实', '实是', '只', '日本', '本金', '金龟', '金龟子', '<EOS>'],
#  ['同样',
#   '的',
#   '这种',
#   '叫做',
#   'dna',
#   '条形',
#   '条形码',
#   '形码',
#   '的',
#   '技术',
#   '真的',
#   '很酷',
#   '你',
#   '可以',
#   '通过',
#   '它',
#   '确认',
#   '你',
#   '吃',
#   '的',
#   '是不是',
#   '不是',
#   '真正',
#   '的',
#   '白鲟',
#   '鲟鱼',
#   '鱼子',
#   '鱼子酱',
#   '是不是',
#   '不是',
#   '真的',
#   '金枪',
#   '金枪鱼',
#   '寿司',
#   '或者',
#   '你',
#   '花',
#   '了',
#   '大',
#   '价钱',
#   '买到',
#   '的',
#   '山羊',
#   '羊乳',
#   '干酪',
#   '是不是',
#   '不是',
#   '真的',
#   '山羊',
#   '羊乳',
#   '<EOS>'],
#  ['作为',
#   '一名',
#   '生物',
#   '黑客',
#   '你',
#   '可以',
#   '分析',
#   '你',
#   '有没有',
#   '没有',
#   '基因',
#   '上',
#   '的',
#   '变异',
#   '<EOS>'],
#  ['你',
#   '可以',
#   '分析',
#   '你',
#   '早餐',
#   '麦片',
#   '里',
#   '的',
#   '转基因',
#   '基因',
#   '成分',
#   '你',
#   '还',
#   '可以',
#   '探索',
#   '你',
#   '的',
#   '祖先',
#   '血统',
#   '<EOS>'],
#  ['把',
#   '气象',
#   '气球',
#   '发送',
#   '发送到',
#   '送到',
#   '平流',
#   '平流层',
#   '采集',
#   '微生',
#   '微生物',
#   '生物',
#   '看看',
#   '里面',
#   '面有',
#   '什么',
#   '<EOS>'],
#  ['你',
#   '可以',
#   '用',
#   '酵母',
#   '当做',
#   '生物',
#   '传感',
#   '传感器',
#   '感器',
#   '来',
#   '检测',
#   '水污染',
#   '污染',
#   '<EOS>'],
#  ['合成', '某种', '生物', '燃料', '细胞', '<EOS>'],
#  ['你', '可以', '做', '无数', '的', '事情', '<EOS>'],
#  ['你',
#   '还',
#   '可以',
#   '进行',
#   '艺术',
#   '艺术科',
#   '术科',
#   '科学',
#   '项目',
#   '有些',
#   '项目',
#   '真的',
#   '很',
#   '赞',
#   '从',
#   '完全',
#   '不同',
#   '的',
#   '角度',
#   '审视',
#   '社会',
#   '和',
#   '生态',
#   '问题',
#   '<EOS>'],
#  ['真的', '很酷', '<EOS>'],
#  ['有人', '会', '问', '为什么', '什么', '我', '要', '参与', '这种', '事儿', '<EOS>'],
#  ['我',
#   '可以',
#   '在',
#   '主流',
#   '科学',
#   '学行',
#   '行业',
#   '里',
#   '有',
#   '很',
#   '好',
#   '的',
#   '工作',
#   '<EOS>'],
#  ['问题',
#   '关键',
#   '是',
#   '在',
#   '这样',
#   '的',
#   '实验',
#   '实验室',
#   '室里',
#   '有些',
#   '东西',
#   '是',
#   '你',
#   '在',
#   '别处',
#   '找',
#   '不到',
#   '的',
#   '有些',
#   '东西',
#   '是',
#   '你',
#   '在',
#   '别处',
#   '找',
#   '不到',
#   '的',
#   '<EOS>'],
#  ['黑客',
#   '空间',
#   '有',
#   '好',
#   '的',
#   '一面',
#   '就是',
#   '你',
#   '可以',
#   '开展',
#   '项目',
#   '而无须',
#   '无须',
#   '向',
#   '任何',
#   '任何人',
#   '何人',
#   '解释',
#   '它',
#   '会',
#   '带来',
#   '丰厚',
#   '的',
#   '利润',
#   '无须',
#   '向',
#   '任何',
#   '任何人',
#   '何人',
#   '解释',
#   '它',
#   '会',
#   '拯救',
#   '救人',
#   '人类',
#   '甚至',
#   '它',
#   '能够',
#   '行得通',
#   '<EOS>'],
#  ['只要', '遵循', '安全', '规定', '<EOS>'],
#  ['如果',
#   '果在',
#   '在世',
#   '世界',
#   '世界各地',
#   '各地',
#   '都',
#   '有',
#   '这样',
#   '的',
#   '地方',
#   '那',
#   '将',
#   '会',
#   '真正',
#   '改变',
#   '人们',
#   '对于',
#   '谁',
#   '才',
#   '有',
#   '资格',
#   '接触',
#   '生物',
#   '生物科技',
#   '科技',
#   '这',
#   '一',
#   '问题',
#   '的',
#   '观念',
#   '<EOS>'],
#  ['就是',
#   '这样',
#   '的',
#   '地方',
#   '推动',
#   '了',
#   '个人',
#   '个人电脑',
#   '电脑',
#   '的',
#   '应用',
#   '和',
#   '传播',
#   '<EOS>'],
#  ['所以',
#   '以为',
#   '为什么',
#   '什么',
#   '不能',
#   '让',
#   '个人',
#   '人生',
#   '生物',
#   '生物科技',
#   '科技',
#   '也',
#   '如此',
#   '呢',
#   '<EOS>'],
#  ['如果',
#   '果在',
#   '在场',
#   '的',
#   '每个',
#   '个人',
#   '都',
#   '参与',
#   '进来',
#   '谁',
#   '都',
#   '想象',
#   '不到',
#   '我们',
#   '能够',
#   '做到',
#   '什么',
#   '<EOS>'],
#  ['这',
#   '是',
#   '个',
#   '全新',
#   '的',
#   '领域',
#   '正如',
#   '刚才',
#   '提到',
#   '布鲁克',
#   '布鲁克林',
#   '鲁克林',
#   '时',
#   '我',
#   '讲到',
#   '的',
#   '还有',
#   '更',
#   '厉害',
#   '的',
#   '呢',
#   '<EOS>'],
#  ['一个', '你', '闻所未闻', '未闻', '的', '口哨', '者', '<EOS>'],
#  ['tedxrotterdam',
#   '大会',
#   '会上',
#   '世界',
#   '口哨',
#   '冠军',
#   '海尔',
#   '尔特',
#   '查特',
#   '特尔',
#   '信手',
#   '信手拈来',
#   '地',
#   '演绎',
#   '了',
#   '一段',
#   '的',
#   'a',
#   '昂',
#   '霍',
#   '夫',
#   '的',
#   '爱',
#   '莲',
#   '以及',
#   '他',
#   '自己',
#   '的',
#   '作品',
#   '美的',
#   '盛宴',
#   '在',
#   '引人',
#   '引人入胜',
#   '的',
#   '幕间',
#   '他',
#   '谈到',
#   '了',
#   '是',
#   '什么',
#   '把',
#   '他',
#   '引入',
#   '了',
#   '这个',
#   '行当',
#   '<EOS>'],
#  ['谢谢', '<EOS>'],
#  ['非常', '非常感谢', '感谢', '<EOS>'],
#  ['这', '就是', '吹口哨', '口哨', '<EOS>'],
#  ['我', '试', '着', '用', '英语', '来说', '<EOS>'],
#  ['好',
#   '一个',
#   '从',
#   '荷兰',
#   '来',
#   '的',
#   '胖胖',
#   '胖胖的',
#   '卷毛',
#   '儿',
#   '的',
#   '家伙',
#   '呀',
#   '他',
#   '为什么',
#   '什么',
#   '要',
#   '吹口哨',
#   '口哨',
#   '<EOS>'],
#  ['事实',
#   '事实上',
#   '我',
#   '大概',
#   '从',
#   '4',
#   '岁',
#   '起',
#   '就',
#   '开始',
#   '吹口哨',
#   '口哨',
#   '了',
#   '<EOS>'],
#  ['我',
#   '爸爸',
#   '总是',
#   '在',
#   '屋子',
#   '周围',
#   '吹口哨',
#   '口哨',
#   '我',
#   '认为',
#   '那',
#   '是',
#   '我家',
#   '家庭',
#   '沟通',
#   '的',
#   '一部',
#   '一部分',
#   '部分',
#   '<EOS>'],
#  ['于是', '我', '开始', '和', '他', '一起', '吹', '<EOS>'],
#  ['事实',
#   '事实上',
#   '直到',
#   '34',
#   '岁',
#   '前',
#   '我',
#   '总是',
#   '用',
#   '吹口哨',
#   '口哨',
#   '烦扰',
#   '甚至',
#   '激怒',
#   '人们',
#   '因为',
#   '说老实话',
#   '老实',
#   '老实话',
#   '实话',
#   '我',
#   '吹口哨',
#   '口哨',
#   '成',
#   '了',
#   '一种',
#   '怪异',
#   '的',
#   '行为',
#   '<EOS>'],
#  ['我', '有时', '独自', '自吹', '有时', '在', '教室', '吹', '<EOS>'],
#  ['有时',
#   '边',
#   '骑',
#   '自行',
#   '自行车',
#   '行车',
#   '边',
#   '吹',
#   '我',
#   '随处',
#   '都',
#   '在',
#   '吹口哨',
#   '口哨',
#   '<EOS>'],
#  ['我', '也', '在', '平安', '平安夜', '派对', '上', '吹', '在', '我', '岳父', '家里', '<EOS>'],
#  ['在我看来', '看来', '他们', '放', '了', '一些', '很糟', '糟糕', '的', '圣诞', '音乐', '<EOS>'],
#  ['当',
#   '我',
#   '听到',
#   '自己',
#   '不',
#   '喜欢',
#   '的',
#   '音乐',
#   '时',
#   '我',
#   '试',
#   '着',
#   '把',
#   '它',
#   '吹',
#   '得',
#   '更好',
#   '<EOS>'],
#  ['红鼻子', '鼻子', '驯鹿', '鲁道夫', '道夫', '你们', '知道', '吧', '<EOS>'],
#  ['它', '也', '可以', '被', '演绎', '成', '这样', '<EOS>'],
#  ['但是',
#   '在',
#   '圣诞',
#   '派对',
#   '上',
#   '确切',
#   '确切的说',
#   '是',
#   '在',
#   '晚餐',
#   '上',
#   '这',
#   '很',
#   '招人',
#   '烦',
#   '<EOS>'],
#  ['所以',
#   '我',
#   '的',
#   '小姨',
#   '小姨子',
#   '几次',
#   '次要',
#   '要求',
#   '我',
#   '别',
#   '再',
#   '吹',
#   '了',
#   '<EOS>'],
#  ['然而', '我', '就是', '停不下', '停不下来', '不下', '下来', '<EOS>'],
#  ['我',
#   '得',
#   '承认',
#   '在',
#   '喝',
#   '了',
#   '点',
#   '小酒',
#   '的',
#   '情况',
#   '下',
#   '我',
#   '冒出',
#   '了',
#   '这',
#   '句',
#   '话',
#   '如果',
#   '有',
#   '那么',
#   '一个',
#   '口哨',
#   '大赛',
#   '我',
#   '就',
#   '去',
#   '参加',
#   '<EOS>'],
#  ['两周', '后', '我', '收到', '了', '一条', '短信', '你', '要', '去', '美国', '啦', '<EOS>'],
#  ['所以', '好', '吧', '我', '要', '去', '美国', '啦', '<EOS>'],
#  ['我', '很', '想去', '但是', '为什么', '什么', '去', '呢', '<EOS>'],
#  ['我', '理所当然', '当然', '地', '立刻', '给', '她', '打', '了', '电话', '<EOS>'],
#  ['她',
#   '谷',
#   '歌',
#   '过',
#   '了',
#   '然后',
#   '后发',
#   '发现',
#   '了',
#   '这个',
#   '世界',
#   '口哨',
#   '锦标',
#   '锦标赛',
#   '当然',
#   '是',
#   '在',
#   '美国',
#   '举办',
#   '的',
#   '<EOS>'],
#  ['她', '没', '认为', '我', '真会', '会去', '那儿', '<EOS>'],
#  ['我会', '丢人', '丢人现眼', '现眼', '的', '<EOS>'],
#  ['我', '不知', '知道', '这么', '用', '英语', '说', '对', '不对', '<EOS>'],
#  ['不过', '在场', '的', '荷兰', '荷兰人', '可以', '明白', '我', '的', '意思', '<EOS>'],
#  ['我', '真的', '丢人', '丢人现眼', '现眼', '了', '<EOS>'],
#  ['她', '想', '他', '不会', '会去', '参加', '的', '<EOS>'],
#  ['但', '事实', '事实上', '我', '去', '了', '<EOS>'],
#  ['我',
#   '到',
#   '了',
#   '北卡罗',
#   '北卡罗来',
#   '北卡罗来纳',
#   '北卡罗来纳州',
#   '卡罗',
#   '罗来纳',
#   '纳州',
#   '的',
#   '路易',
#   '路易斯',
#   '堡',
#   '在',
#   '美国',
#   '东南',
#   '东南部',
#   '南部',
#   '我',
#   '随之',
#   '走进',
#   '了',
#   '口哨',
#   '的',
#   '世界',
#   '<EOS>'],
#  ['我',
#   '也',
#   '进入',
#   '了',
#   '世界',
#   '锦标',
#   '锦标赛',
#   '并且',
#   '赢得',
#   '了',
#   '2004',
#   '年',
#   '的',
#   '冠军',
#   '<EOS>'],
#  ['这', '这', '当然', '很', '有趣', '<EOS>'],
#  ['为了',
#   '捍卫',
#   '了',
#   '自己',
#   '的',
#   '头衔',
#   '你',
#   '知道',
#   '像',
#   '男人',
#   '或者',
#   '运动',
#   '运动员',
#   '动员',
#   '那样',
#   '我',
#   '想',
#   '2005',
#   '年',
#   '再',
#   '去',
#   '一次',
#   '吧',
#   '然后',
#   '我',
#   '就',
#   '又',
#   '赢',
#   '了',
#   '一次',
#   '<EOS>'],
#  ['之后', '我', '有', '几年', '不能', '参赛', '<EOS>'],
#  ['再',
#   '之后',
#   '2008',
#   '年',
#   '我',
#   '又',
#   '参加',
#   '了',
#   '一次',
#   '在',
#   '日本',
#   '东京',
#   '并且',
#   '我',
#   '又',
#   '赢',
#   '了',
#   '<EOS>'],
#  ['于是',
#   '就',
#   '有',
#   '了',
#   '现在',
#   '这个',
#   '站',
#   '在',
#   '鹿特丹',
#   '这',
#   '座',
#   '优美',
#   '美的',
#   '城市',
#   '中',
#   '一个',
#   '大',
#   '舞台',
#   '台上',
#   '上演',
#   '演讲',
#   '的',
#   '我',
#   '讲述',
#   '着',
#   '关于',
#   '口哨',
#   '的',
#   '事情',
#   '<EOS>'],
#  ['事实', '事实上', '我', '现在', '靠', '吹口哨', '口哨', '赚钱', '<EOS>'],
#  ['于是', '我', '辞去', '了', '护士', '的', '工作', '<EOS>'],
#  ['我',
#   '试图',
#   '实现',
#   '我',
#   '的',
#   '梦想',
#   '其实',
#   '实事',
#   '事实',
#   '事实上',
#   '这根',
#   '根本',
#   '不是',
#   '我',
#   '的',
#   '梦想',
#   '但',
#   '它',
#   '听',
#   '上去',
#   '好极了',
#   '极了',
#   '<EOS>'],
#  ['各位', '我', '并', '不是', '在场', '唯一', '吹口哨', '口哨', '的', '<EOS>'],
#  ['你', '会', '说', '呃', '你', '什么', '意思', '<EOS>'],
#  ['好', '的', '事实', '事实上', '大家', '要', '一起', '吹', '<EOS>'],
#  ['接着',
#   '总是',
#   '会',
#   '发生',
#   '同样',
#   '的',
#   '事',
#   '人们',
#   '面面',
#   '面面相觑',
#   '面相',
#   '觑',
#   '心里',
#   '暗想',
#   '哦',
#   '天',
#   '哪',
#   '<EOS>'],
#  ['为什么', '什么', '要', '这样', '我', '可以', '走', '吗', '<EOS>'],
#  ['不', '你', '不行', '<EOS>'],
#  ['事实', '事实上', '这', '很', '简单', '<EOS>'],
#  ['我', '要', '吹', '的', '这段', '叫', '美的', '盛宴', '<EOS>'],
#  ['大概', '80', '分钟', '长', '<EOS>'],
#  ['不', '不', '不', '它', '只有', '4', '分钟', '长', '<EOS>'],
#  ['我',
#   '首先',
#   '想',
#   '和',
#   '你们',
#   '彩排',
#   '一下',
#   '你们',
#   '的',
#   '口哨',
#   '口哨声',
#   '哨声',
#   '<EOS>'],
#  ['我', '吹', '一声', '<EOS>'],
#  ['对不起', '我', '忘', '了', '一件', '事', '<EOS>'],
#  ['你们', '和', '我', '吹', '一个', '调', '<EOS>'],
#  ['我', '听到', '了', '各种', '音调', '<EOS>'],
#  ['这', '前景', '很', '好', '<EOS>'],
#  ['这', '前景', '很', '好', '<EOS>'],
#  ['我', '请', '技术', '技术人员', '人员', '放', '一下', '音乐', '<EOS>'],
#  ['当',
#   '音乐',
#   '响起',
#   '起来',
#   '来时',
#   '我会',
#   '会指',
#   '指出',
#   '你们',
#   '在',
#   '哪儿',
#   '跟着',
#   '吹',
#   '我们',
#   '一起',
#   '起来',
#   '来见',
#   '见证',
#   '将',
#   '会',
#   '发生',
#   '什么',
#   '<EOS>'],
#  ['哦', '呵呵', '<EOS>'],
#  ['很', '抱歉', '技术', '技术人员', '人员', '<EOS>'],
#  ['我', '太', '习惯', '请', '技术', '技术人员', '人员', '帮助', '了', '<EOS>'],
#  ['我', '自己', '来', '播放', '<EOS>'],
#  ['好', '的', '开始', '了', '<EOS>'],
#  ['好', '的', '<EOS>'],
#  ['这', '很', '简单', '不是', '吗', '<EOS>'],
#  ['现在', '到', '了', '独奏', '部分', '我', '打算', '自己', '来', '演绎', '<EOS>'],
#  ['马克',
#   '马克思',
#   '威斯',
#   '威斯特',
#   '斯特',
#   '斯特曼',
#   '特曼',
#   '海尔',
#   '尔特',
#   '查特',
#   '特尔',
#   '世界',
#   '口哨',
#   '冠军',
#   '<EOS>'],
#  ['海尔', '尔特', '查特', '特尔', '谢谢', '谢谢', '<EOS>'],
#  ['马克', '肖', '一个', '非常', '干燥', '的', '演示', '<EOS>'],
#  ['马克',
#   '肖',
#   '为',
#   '我',
#   '們',
#   '演示',
#   '了',
#   '极度',
#   '干燥',
#   '一种',
#   '可以',
#   '非常',
#   '常有',
#   '有效',
#   '的',
#   '防水',
#   '和',
#   '水性',
#   '材料',
#   '的',
#   '涂层',
#   '在',
#   '纳米',
#   '纳米级',
#   '上',
#   '这个',
#   '涂层',
#   '会',
#   '在',
#   '表面',
#   '形成',
#   '一层',
#   '空气',
#   '保护',
#   '保护伞',
#   '防止',
#   '止水',
#   '的',
#   '渗入',
#   '来看',
#   '看看',
#   '这',
#   '激动',
#   '激动人心',
#   '动人',
#   '人心',
#   '的',
#   '两分',
#   '两分钟',
#   '分钟',
#   '吧',
#   '<EOS>'],
#  ['我',
#   '来',
#   '给',
#   '大家',
#   '展示',
#   '认识',
#   '我们',
#   '看不到',
#   '不到',
#   '的',
#   '东西',
#   '是',
#   '件',
#   '多么',
#   '有趣',
#   '的',
#   '事情',
#   '<EOS>'],
#  ['你们',
#   '马上',
#   '要',
#   '体验',
#   '到',
#   '一种',
#   '全新',
#   '的',
#   '已经',
#   '可用',
#   '的',
#   '令人',
#   '令人激动',
#   '激动',
#   '的',
#   '科技',
#   '如何',
#   '能',
#   '让',
#   '我们',
#   '的',
#   '生活',
#   '保持',
#   '干爽',
#   '<EOS>'],
#  ['我',
#   '这边',
#   '有',
#   '一块',
#   '一块儿',
#   '块儿',
#   '煤渣',
#   '砖',
#   '我们',
#   '在',
#   '它',
#   '的',
#   '半面',
#   '喷上',
#   '了',
#   '纳米',
#   '纳米技术',
#   '技术',
#   '涂层',
#   '这种',
#   '涂层',
#   '几乎',
#   '可以',
#   '在',
#   '任何',
#   '材料',
#   '上',
#   '使用',
#   '<EOS>'],
#  ['它',
#   '叫做',
#   '极度',
#   '干燥',
#   '当',
#   '你',
#   '把',
#   '它',
#   '用',
#   '在',
#   '任何',
#   '材料',
#   '上',
#   '时',
#   '它',
#   '会',
#   '变成',
#   '一层',
#   '超',
#   '疏水',
#   '保护',
#   '保护层',
#   '<EOS>'],
#  ['看',
#   '煤渣',
#   '砖',
#   '这边',
#   '没有',
#   '涂',
#   '保护',
#   '保护层',
#   '的',
#   '地方',
#   '大家',
#   '可以',
#   '看到',
#   '水',
#   '渗进',
#   '渗进去',
#   '进去',
#   '了',
#   '<EOS>'],
#  ['没有', '渗进', '渗进去', '进去', '<EOS>'],
#  ['渗水', '不', '渗水', '<EOS>'],
#  ['那么', '什么', '是', '超', '疏水', '<EOS>'],
#  ['它', '是', '用来', '测量', '一个', '表面', '面上', '的', '水滴', '的', '<EOS>'],
#  ['水滴',
#   '越',
#   '圆',
#   '越',
#   '疏水',
#   '如果',
#   '水滴',
#   '非常',
#   '圆',
#   '的话',
#   '就',
#   '叫',
#   '超',
#   '疏水',
#   '了',
#   '<EOS>'],
#  ['刚',
#   '上过',
#   '蜡',
#   '的',
#   '汽车',
#   '水分',
#   '水分子',
#   '分子',
#   '与',
#   '平面',
#   '的',
#   '接触',
#   '接触角',
#   '触角',
#   '弧度',
#   '突降',
#   '降到',
#   '大概',
#   '90',
#   '度',
#   '<EOS>'],
#  ['一扇', '挡风', '挡风玻璃', '玻璃', '涂层', '大概', '是', '110', '度', '<EOS>'],
#  ['但是',
#   '你',
#   '看',
#   '这边',
#   '是',
#   '160',
#   '到',
#   '175',
#   '度',
#   '之间',
#   '所有',
#   '超过',
#   '150',
#   '度',
#   '的',
#   '都',
#   '叫做',
#   '超',
#   '疏水',
#   '<EOS>'],
#  ['接下',
#   '接下来',
#   '下来',
#   '的',
#   '一个',
#   '演示',
#   '我',
#   '有',
#   '一双',
#   '双手',
#   '手套',
#   '其中',
#   '一只',
#   '涂',
#   '了',
#   '纳米',
#   '科技',
#   '涂层',
#   '看看',
#   '大家',
#   '能',
#   '不能',
#   '看出',
#   '是',
#   '哪一只',
#   '一只',
#   '我',
#   '来',
#   '给',
#   '你们',
#   '一个',
#   '提示',
#   '<EOS>'],
#  ['大家', '猜', '的', '是', '干', '的', '那', '只', '吗', '<EOS>'],
#  ['当',
#   '我们',
#   '有',
#   '了',
#   '纳米',
#   '科技',
#   '和',
#   '纳米',
#   '科学',
#   '我们',
#   '现在',
#   '就',
#   '可以',
#   '了解',
#   '原子',
#   '和',
#   '分子',
#   '让',
#   '它们',
#   '造福',
#   '造福人类',
#   '福人',
#   '人类',
#   '<EOS>'],
#  ...]

# %% [markdown]
# ### Data Loader

# %%
class TranslationDataset(Dataset):   # inherits torch.utils.data.Dataset
    """ 
    Class that represents a train/validation/test/dataset that's readable for Pytorch. 
    """
    def __init__(self, src_indices, targ_indices, src_max_sentence_len, targ_max_sentence_len):
        """ 
        Initialize dataset by passing in a list of input indices and a list of output indices 
        """
        self.src_indices = src_indices
        self.targ_indices = targ_indices
        self.src_max_sentence_len = src_max_sentence_len
        self.targ_max_sentence_len = targ_max_sentence_len
        assert (len(self.src_indices) == len(self.targ_indices))
        
    def __len__(self): 
        return len(self.src_indices)
    
    def __getitem__(self, key): 
        """ 
        Triggered when dataset[i] is called, outputs lists of input and output indices, as well as their 
        respective lengths
        """
        src_idx = self.src_indices[key][:self.src_max_sentence_len]
        src_len = len(src_idx)
        targ_idx = self.targ_indices[key][:self.targ_max_sentence_len]
        targ_len = len(targ_idx)
        return [src_idx, targ_idx, src_len, targ_len]
    

def collate_func(src_max_sentence_len, targ_max_sentence_len, batch): 
    """ 
    Customized function for DataLoader that dynamically pads the batch so that all data have the same length
    """
    src_idxs = [] 
    targ_idxs = [] 
    src_lens = [] 
    targ_lens = [] 
    
    for datum in batch: 
        # append original lengths of sequences 
        src_lens.append(datum[2]) 
        targ_lens.append(datum[3])
        
        # pad sequences before appending 
        src_idx_padded = np.pad(array=np.array(datum[0]), pad_width = ((0, src_max_sentence_len - datum[2])), 
                                mode='constant', constant_values=RESERVED_TOKENS['<PAD>'])
        targ_idx_padded = np.pad(array=np.array(datum[1]), pad_width = ((0, targ_max_sentence_len - datum[3])),
                                 mode='constant', constant_values=RESERVED_TOKENS['<PAD>'])
        src_idxs.append(src_idx_padded)
        targ_idxs.append(targ_idx_padded)
    
    return [torch.from_numpy(np.array(src_idxs)), torch.from_numpy(np.array(targ_idxs)), 
            torch.LongTensor(src_lens), torch.LongTensor(targ_lens)]


def create_dataloaders(processed_data, src_max_sentence_len, targ_max_sentence_len, batch_size): 
    """ 
    Takes processed_data as dictionary output from process_data function, maximum sentence lengths, 
    outputs a nested dictionary called 'loaders' that holds train, dev, and test loaders, 
    e.x. loaders['dev'] holds the data loader for dev/validation set 
    """
    loaders = {} 
    for split in ['train', 'dev', 'test']: 
        dataset = TranslationDataset(processed_data[split]['source']['indices'], processed_data[split]['target']['indices'], 
                                     src_max_sentence_len, targ_max_sentence_len)
        loaders[split] = DataLoader(dataset, batch_size=batch_size, shuffle=False, 
                                    collate_fn=partial(collate_func, src_max_sentence_len, targ_max_sentence_len))
    return loaders

# %%
BATCH_SIZE = 32
loaders_full = create_dataloaders(data, SRC_MAX_SENTENCE_LEN, TARG_MAX_SENTENCE_LEN, BATCH_SIZE)

# %% [markdown]
# ### Model Architecture

# %% [markdown]
# #### Get Pretrained Word Embedding

# %%
def get_pretrained_emb(word2vec, token2id): 
    """ 
    Given word2vec model and vocab's token2id, generate pretrained word embeddings for all tokens in vocab. 
    For tokens not in the word2vec model, initialize with random vectors using normal distribution 
    """

    pretrained_emb = np.zeros((len(token2id), 300)) 
    for token in token2id: 
        try: 
            pretrained_emb[token2id[token]] = word2vec[token]
        except:
            pretrained_emb[token2id[token]] = np.random.normal(size=(300,))
    return torch.from_numpy(pretrained_emb.astype(np.float32)).to(device)

# %% [markdown]
# #### RNN Encoder Decoder

# %%
class EncoderRNN(nn.Module): # previously EncoderSimpleRNN_Test

    """ 
    Concats bidirectional hidden/output. 
    """ 
    def __init__(self, rnn_cell_type, enc_hidden_dim, num_layers, enc_dropout, src_max_sentence_len, pretrained_word2vec):
        super(EncoderRNN, self).__init__()
        self.enc_embed_dim = 300
        self.enc_hidden_dim = enc_hidden_dim 
        self.enc_dropout = enc_dropout 
        self.src_max_sentence_len = src_max_sentence_len
        self.num_layers = num_layers
        self.embedding = nn.Embedding.from_pretrained(pretrained_word2vec, freeze=True) 
        self.rnn_cell_type = rnn_cell_type 
        if self.rnn_cell_type == 'gru': 
            self.rnn = nn.GRU(input_size=self.enc_embed_dim, hidden_size=self.enc_hidden_dim, 
                              num_layers=self.num_layers, dropout = enc_dropout, batch_first=True, bidirectional=True) 
        elif self.rnn_cell_type == 'lstm': 
            self.rnn = nn.LSTM(input_size=self.enc_embed_dim, hidden_size=self.enc_hidden_dim, 
                               num_layers=self.num_layers, dropout = enc_dropout, batch_first=True, bidirectional=True) 

    def forward(self, enc_input, enc_input_lens):
        batch_size = enc_input.size()[0]
        _, idx_sort = torch.sort(enc_input_lens, dim=0, descending=True)
        _, idx_unsort = torch.sort(idx_sort, dim=0)
        enc_input, enc_input_lens = enc_input.index_select(0, idx_sort), enc_input_lens.index_select(0, idx_sort)
        embedded = self.embedding(enc_input)
        embedded = torch.nn.utils.rnn.pack_padded_sequence(embedded, enc_input_lens, batch_first=True)
        hidden = self.initHidden(batch_size) #.to(device)
        if self.rnn_cell_type == 'gru': 
            output, hidden = self.rnn(embedded, hidden)
        elif self.rnn_cell_type == 'lstm': 
            memory = self.initHidden(batch_size) #.to(device)
            output, (hidden, memory) = self.rnn(embedded, (hidden, memory)) 
        output, _ = torch.nn.utils.rnn.pad_packed_sequence(output, batch_first=True, total_length=self.src_max_sentence_len,
                                                            padding_value=RESERVED_TOKENS['<PAD>'])
        output = output.index_select(0, idx_unsort)
        hidden = hidden.index_select(1, idx_unsort)
        #output = output[:, :, :self.enc_hidden_dim] + output[:, :, self.enc_hidden_dim:]
        output = torch.cat([output[:, :, :self.enc_hidden_dim], output[:, :, self.enc_hidden_dim:]], dim=2)
        hidden = hidden.view(self.num_layers, 2, batch_size, self.enc_hidden_dim)
        #hidden = hidden[:, 0, :, :].squeeze(dim=1) + hidden[:, 1, :, :].squeeze(dim=1)
        hidden = torch.cat([hidden[:, 0, :, :].view(self.num_layers, 1, batch_size, self.enc_hidden_dim).squeeze(dim=1), 
                        hidden[:, 1, :, :].view(self.num_layers, 1, batch_size, self.enc_hidden_dim).squeeze(dim=1)], dim=2) 
        hidden = hidden.view(self.num_layers, batch_size, 2 * self.enc_hidden_dim)

        return output, hidden

    def initHidden(self, batch_size):
        return torch.zeros(2*self.num_layers, batch_size, self.enc_hidden_dim).to(device)


class DecoderRNN(nn.Module): 

    """ 
    Vanilla decoder without attention, but final layer from encoder is repeatedly passed as input to each time step. 
    Handles output from EncoderRNN, which concats bidirectional output. 
    """ 

    def __init__(self, dec_hidden_dim, enc_hidden_dim, num_layers, targ_vocab_size, targ_max_sentence_len, pretrained_word2vec):
        super(DecoderRNN, self).__init__()
        self.dec_embed_dim = 300
        self.dec_hidden_dim = dec_hidden_dim 
        self.enc_hidden_dim = enc_hidden_dim
        self.targ_vocab_size = targ_vocab_size
        self.targ_max_sentence_len = targ_max_sentence_len
        self.num_layers = num_layers
        self.embedding = nn.Embedding.from_pretrained(pretrained_word2vec, freeze=True) 
        self.gru = nn.GRU(self.dec_embed_dim + 2 * self.enc_hidden_dim, self.dec_hidden_dim, num_layers=self.num_layers) 
        self.out = nn.Linear(dec_hidden_dim, self.targ_vocab_size) 
        self.softmax = nn.LogSoftmax(dim=1) 

    def forward(self, dec_input, dec_hidden, enc_outputs): 
        dec_input = dec_input 
        dec_hidden = dec_hidden 
        enc_outputs = enc_outputs 
        batch_size = dec_input.size()[0]
        embedded = self.embedding(dec_input).view(1, batch_size, -1)
        #context = enc_outputs[:, -1, :].unsqueeze(dim=1).transpose(0, 1) 
        context = torch.cat([enc_outputs[:, -1, :self.enc_hidden_dim], 
                             enc_outputs[:, 0, self.enc_hidden_dim:]], dim=1).unsqueeze(0)
        concat = torch.cat([embedded, context], 2) 
        output, hidden = self.gru(concat, dec_hidden)
        output = self.softmax(self.out(output[0]))  
        return output, hidden


class EncoderDecoder(nn.Module): 

    """ 
    Encoder-Decoder without attention 
    """

    def __init__(self, encoder, decoder, decoder_token2id): 
        super(EncoderDecoder, self).__init__() 
        self.encoder = encoder 
        self.decoder = decoder 
        self.targ_vocab_size = self.decoder.targ_vocab_size
        self.src_max_sentence_len = self.encoder.src_max_sentence_len 
        self.targ_max_sentence_len = self.decoder.targ_max_sentence_len 

    def forward(self, src_idx, targ_idx, src_lens, targ_lens, teacher_forcing_ratio): 
        
        batch_size = src_idx.size()[0]
        enc_outputs, enc_hidden = self.encoder(src_idx, src_lens)
        dec_hidden = enc_hidden 
        dec_outputs = Variable(torch.zeros(self.targ_max_sentence_len, batch_size, self.targ_vocab_size))
        hypotheses = Variable(torch.zeros(self.targ_max_sentence_len, batch_size))
        dec_output = targ_idx[:, 0] 

        for di in range(1, self.targ_max_sentence_len): 
            dec_output, dec_hidden = self.decoder(dec_output, dec_hidden, enc_outputs)
            dec_outputs[di] = dec_output 
            teacher_labels = targ_idx[:, di-1] 
            greedy_labels = dec_output.data.max(1)[1]
            dec_output = teacher_labels if random.random() < teacher_forcing_ratio else greedy_labels 
            hypotheses[di] = greedy_labels

        attn_placeholder = Variable(torch.zeros(batch_size, self.targ_max_sentence_len, self.src_max_sentence_len))

        return dec_outputs, hypotheses.transpose(0,1), attn_placeholder

# %% [markdown]
# #### Attention

# %%
class Attention(nn.Module): 
    
    """ 
    Implements additive attention
    """ 
    
    def __init__(self, enc_hidden_dim, dec_hidden_dim, num_annotations, num_layers): 
        super(Attention, self).__init__() 
        self.dec_hidden_dim = dec_hidden_dim
        self.input_dim = 2 * enc_hidden_dim + self.dec_hidden_dim
        self.attn = nn.Linear(self.input_dim, self.dec_hidden_dim) 
        self.v = nn.Parameter(torch.rand(self.dec_hidden_dim))
        self.num_layers = num_layers 
        nn.init.normal_(self.v, mean=0, std=1. / math.sqrt(self.dec_hidden_dim))

    def forward(self, encoder_outputs, last_dec_hidden, src_idx): 
        time_steps = encoder_outputs.size()[1]
        batch_size = encoder_outputs.size()[0]
        v_broadcast = self.v.repeat(batch_size, 1, 1) #.to(device) # [B, 1, H]
        last_dec_hidden = last_dec_hidden.transpose(0, 1)[:, -1, :].unsqueeze(1) # [B, L, H] -> [B, 1, H] -> [B, H] (take last layer)
        hidden_broadcast = last_dec_hidden.repeat(1, time_steps, 1) #.to(device) # [B, T, H]
        concat = torch.cat([encoder_outputs, hidden_broadcast], dim=2) #.to(device) # [B, T, 2H]
        energies = torch.tanh(self.attn(concat)).transpose(1, 2) # [B, T, H] -> [B, H, T]
        energies = torch.bmm(v_broadcast, energies).squeeze(1) # [B, 1, H] * [B, H, T] -> [B, 1, T] -> [B, T]
        energies.data.masked_fill_(src_idx == RESERVED_TOKENS['<PAD>'], -float('inf'))
        attn_weights = F.softmax(energies, dim=1) # [B, T]

        return attn_weights


class DotAttention(nn.Module): 

    """ Implements multiplicative attention """

    def __init__(self, enc_hidden_dim, dec_hidden_dim, num_annotations, num_layers): 
        super(DotAttention, self).__init__() 
        self.dec_hidden_dim = dec_hidden_dim
        self.num_layers = num_layers 

    def forward(self, encoder_outputs, last_dec_hidden, src_idx): 
        time_steps = encoder_outputs.size()[1]
        batch_size = encoder_outputs.size()[0]
        last_dec_hidden = last_dec_hidden.transpose(0, 1)[:, -1, :].view(batch_size, 1, -1) # [B, L, H] -> [B, 1, H]
        energies = torch.bmm(encoder_outputs, last_dec_hidden.transpose(1, 2)).squeeze(-1)  # [B, T, H] * [B, H, 1] -> [B, T, 1] -> [B, T]
        energies.data.masked_fill_(src_idx == RESERVED_TOKENS['<PAD>'], -float('inf'))
        attn_weights = F.softmax(energies, dim=1) # [B, T]

        return attn_weights

# %% [markdown]
# #### Encoder Decoder with Attention

# %%
class DecoderAttnRNN(nn.Module):

    """ 
    Decoder with attention
    """ 

    def __init__(self, rnn_cell_type, dec_hidden_dim, enc_hidden_dim, num_layers, dec_dropout, targ_vocab_size, 
                    src_max_sentence_len, targ_max_sentence_len, attention_type, pretrained_word2vec):

        super(DecoderAttnRNN, self).__init__()
        self.dec_embed_dim = 300
        self.dec_hidden_dim = dec_hidden_dim 
        self.enc_hidden_dim = enc_hidden_dim
        self.src_max_sentence_len = src_max_sentence_len
        self.targ_max_sentence_len = targ_max_sentence_len
        self.targ_vocab_size = targ_vocab_size
        self.num_layers = num_layers 
        self.rnn_cell_type = rnn_cell_type 
        self.embedding = nn.Embedding.from_pretrained(pretrained_word2vec, freeze=True) 
        # choose attention type 
        if attention_type == 'additive': 
            self.attn = Attention(self.enc_hidden_dim, self.dec_hidden_dim, 
                                    num_annotations = self.src_max_sentence_len, num_layers=self.num_layers) 
        elif attention_type == 'multiplicative': 
            self.attn = DotAttention(self.enc_hidden_dim, self.dec_hidden_dim, 
            num_annotations = self.src_max_sentence_len, num_layers=self.num_layers) 
        # choose RNN cell type 
        if self.rnn_cell_type == 'gru':
            self.rnn = nn.GRU(self.dec_embed_dim + 2 * self.enc_hidden_dim, self.dec_hidden_dim, num_layers=self.num_layers, dropout=dec_dropout) 
        elif self.rnn_cell_type == 'lstm': 
            self.rnn = nn.LSTM(self.dec_embed_dim + 2 * self.enc_hidden_dim, self.dec_hidden_dim, num_layers=self.num_layers, dropout=dec_dropout) 
        self.out = nn.Linear(self.dec_hidden_dim, self.targ_vocab_size) 
        self.softmax = nn.LogSoftmax(dim=1) 

    def forward(self, dec_input, dec_hidden, enc_outputs, src_idx):
        batch_size = dec_input.size()[0]
        embedded = self.embedding(dec_input).view(1, batch_size, -1) # [1, B, H]
        attn_weights = self.attn(encoder_outputs=enc_outputs, last_dec_hidden=dec_hidden, src_idx=src_idx).unsqueeze(1) # [B, 1, T]
        context = attn_weights.bmm(enc_outputs).transpose(0, 1) # [B, 1, T] * [B, T, H] = [B, 1, H] -> [1, B, H]
        concat = torch.cat([embedded, context], 2) # [1, B, 2H] 
        if self.rnn_cell_type == 'gru':
             output, hidden = self.rnn(concat, dec_hidden) # [1, B, H], [2, B, H] 
        elif self.rnn_cell_type == 'lstm':
            output, (hidden, memory) = self.rnn(concat, (dec_hidden, dec_hidden))		
        output = self.softmax(self.out(output[0])) # [B, H] -> [B, V] 

        return output, hidden, attn_weights 


class EncoderDecoderAttn(nn.Module): 

    """ 
    Encoder Decoder with Attention 
    """

    def __init__(self, encoder, decoder, decoder_token2id): 
        super(EncoderDecoderAttn, self).__init__() 
        self.encoder = encoder 
        self.decoder = decoder 
        self.targ_vocab_size = self.decoder.targ_vocab_size
        self.src_max_sentence_len = self.encoder.src_max_sentence_len 
        self.targ_max_sentence_len = self.decoder.targ_max_sentence_len 

    def forward(self, src_idx, targ_idx, src_lens, targ_lens, teacher_forcing_ratio): 

        batch_size = src_idx.size()[0]
        enc_outputs, enc_hidden = self.encoder(src_idx, src_lens)
        dec_hidden = enc_hidden 
        dec_outputs = Variable(torch.zeros(self.targ_max_sentence_len, batch_size, self.targ_vocab_size))
        hypotheses = Variable(torch.zeros(self.targ_max_sentence_len, batch_size))
        attn_weights_all = Variable(torch.zeros(self.targ_max_sentence_len, batch_size, self.targ_max_sentence_len))
        dec_output = targ_idx[:, 0] 

        for di in range(1, self.targ_max_sentence_len): 
            dec_output, dec_hidden, attn_weights = self.decoder(dec_output, dec_hidden, enc_outputs, src_idx) # src_idx for masking 
            dec_outputs[di] = dec_output 
            teacher_labels = targ_idx[:, di-1] 
            greedy_labels = dec_output.data.max(1)[1]
            dec_output = teacher_labels if random.random() < teacher_forcing_ratio else greedy_labels 
            hypotheses[di] = greedy_labels
            attn_weights_all[di] = attn_weights.squeeze(1)

        return dec_outputs, hypotheses.transpose(0,1), attn_weights_all.transpose(0,1)


class EncoderCNN(nn.Module):
    """
    CNN Encoder
    """
    def __init__(self, pretrained_word2vec, src_max_sentence_len=10, enc_hidden_dim=512, dropout=0.1):
        super(EncoderCNN, self).__init__()
        self.enc_embed_dim = 300
        self.enc_hidden_dim = enc_hidden_dim
        self.embedding = nn.Embedding.from_pretrained(pretrained_word2vec, freeze=True).to(device)
        self.conv1_a = nn.Conv1d(300, enc_hidden_dim, kernel_size=3, padding=1).to(device)
        self.conv2_a = nn.Conv1d(enc_hidden_dim, enc_hidden_dim, kernel_size=3, padding=1).to(device)
        self.conv1_b = nn.Conv1d(300, enc_hidden_dim, kernel_size=3, padding=1).to(device)
        self.conv2_b = nn.Conv1d(enc_hidden_dim, enc_hidden_dim, kernel_size=3, padding=1).to(device)
        self.dropout_val = dropout
        self.src_max_sentence_len = src_max_sentence_len


        def forward(self, enc_input, enc_input_lens):
            enc_input = enc_input.to(device)
            enc_input_lens = enc_input_lens.to(device)
            batch_size = enc_input.size()[0]
            embedded = self.embedding(enc_input)
            embedded = F.dropout(embedded, self.dropout_val)

            # 1st net
            hidden_1_a = self.conv1_a(embedded.transpose(1,2)).transpose(1,2)
            #print(hidden_1_a.shape)
            hidden_1_a.contiguous().view(-1, hidden_1_a.size(-1))
            hidden_1_a = F.leaky_relu(hidden_1_a.contiguous().view(-1, self.enc_embed_dim)).view(batch_size, -1, hidden_1_a.size(-1))
            hidden_2_a = self.conv2_a(hidden_1_a.transpose(1,2)).transpose(1,2)
            hidden_2_a = F.leaky_relu(hidden_2_a.contiguous().view(-1, hidden_2_a.size(-1))).view(batch_size, -1, hidden_2_a.size(-1))
            # 2nd net
            hidden_1_b = self.conv1_a(embedded.transpose(1,2)).transpose(1,2)
            hidden_1_b.contiguous().view(-1, hidden_1_b.size(-1))
            hidden_1_b = F.leaky_relu(hidden_1_b.contiguous().view(-1, self.enc_embed_dim)).view(batch_size, -1, hidden_1_b.size(-1))
            hidden_2_b = self.conv2_a(hidden_1_b.transpose(1,2)).transpose(1,2)
            hidden_2_b = F.leaky_relu(hidden_2_b.contiguous().view(-1, hidden_2_b.size(-1))).view(batch_size, -1, hidden_2_b.size(-1))
            hidden_2_b = hidden_2_b.view(-1, 2, batch_size, self.enc_hidden_dim)
            hidden_2_b = hidden_2_b.transpose(0,1)

            hidden_2_b = hidden_2_b[:, 0, :, :].squeeze(dim=1) + hidden_2_b[:, 1, :, :].squeeze(dim=1)

            return hidden_2_a , hidden_2_b.view(2,batch_size, -1)
